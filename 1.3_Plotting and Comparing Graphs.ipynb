# %% [markdown]
# ## Automatic Harmonic Analysis Based on Trajectory constructions and Graph reduction

# %% [markdown]
# The block performs automatic Harmonic analysis. It asks for a directory of midi files (preferably of the same style). It asks a name of composer whose works are contained in the music21.Coprus. It also analyzes 200 Bach Chorales. Last it asks for a directory to save the plotted graphs. The program also prints :
# - The most distant point of each distribution
# - The most relevant pieces beetween styles
# - a sorted list of pieces in correlation with the mean of each distribution

# %%
import TestingModule
# Out:
# Enter the directory of your files : Midi_files/Classical/Beethoven
# What is the style of the directory?Beethoven_quartets
# Enter A Composer's Name : beethoven
# Enter the directory to save the plots : Graphs
# Building Trajectory for  C:\Users\melki\AppData\Local\Programs\Python\Python36-32\Lib\site-packages\music21\corpus\beethoven\opus132.mxl
# Building Trajectory for  C:\Users\melki\AppData\Local\Programs\Python\Python36-32\Lib\site-packages\music21\corpus\beethoven\opus133.mxl
# Building Trajectory for  C:\Users\melki\AppData\Local\Programs\Python\Python36-32\Lib\site-packages\music21\corpus\beethoven\opus18no1\movement1.krn
# Building Trajectory for  C:\Users\melki\AppData\Local\Programs\Python\Python36-32\Lib\site-packages\music21\corpus\beethoven\opus18no1\movement1.mxl
# Building Trajectory for  C:\Users\melki\AppData\Local\Programs\Python\Python36-32\Lib\site-packages\music21\corpus\beethoven\opus18no1\movement2.krn
# ...
