# %% [markdown]
# ## Reading the midi File and finding the chords

# %%
from Tonnetz_Select import fromMidiToPCS
from structural_functions import testInput
from os.path import isdir

# %% [markdown]
# Will ask you the directory and the name of the file and returns the Modified list of chords and the appropriate Tonnetz

# %%
print("Enter the directory of the MIDI file")
directory = testInput(isdir)
file = input("Enter the name of the MIDI file(without the extension)")
complete_name = directory + '/' + file + '.mid'
chordListConnectNoDoubles, Tonnetz = fromMidiToPCS(complete_name)
print(file, "is complete with Tonnetz", Tonnetz)
# Out:
# Enter the directory of the MIDI file
# haydn_cmaj
# Invalid input, try again
# Midi_files
# Enter the name of the MIDI file(without the extension)midi_export
# 17
# midi_export is complete with Tonnetz [2, 3, 7]

# %% [markdown]
# ## Trajectory Calculations

# %% [markdown]
# ### Computing Trajectory (Attention trjectory is an object !)

# %%
from TrajectoryCalculationsWithClass import *

# %%
trajectory = NewTrajectory(chordListConnectNoDoubles, Tonnetz)
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# <ipython-input-4-e60bcea56ecf> in <module>
# ----> 1 trajectory = NewTrajectory(chordListConnectNoDoubles, Tonnetz)
#
# ~\Desktop\Paris_Telecom\Music Style Classification\TrajectoryCalculationsWithClass.py in NewTrajectory(listOfChords, Tonnetz, origin)
#     378             listOfChords[0],
#     379             origin,
# --> 380             Tonnetz),
#     381         listOfChords,
#     382         Tonnetz)
#
# ~\Desktop\Paris_Telecom\Music Style Classification\TrajectoryCalculationsWithClass.py in ChordConfiguration(chord, axes, Tonnetz)
#     107             if(noteA in coordDict and noteB not in coordDict):
#     108                 newPoint = intervalToPoint(
# --> 109                     (noteB - noteA) % 12, coordDict[noteA], Tonnetz)
#     110                 if isValidPos(newPoint):
#     111                     coordDict[noteB] = newPoint
#
# ~\Desktop\Paris_Telecom\Music Style Classification\TrajectoryCalculationsWithClass.py in intervalToPoint(interval, point, T_axes)
#      70     movementDict = axesMovementsDict(T_axes, point)
#      71     try:
# ---> 72         point = movementDict[interval]
#      73     # here is the definition of Invalid Positions
#      74     except ValueError:
#
# KeyError: 4

# %% [markdown]
# ### Let's find the edges

# %%
import itertools as itt
def TrajectoryNoteEdges(TrajectoryPoints, Tonnetz):
    TotalEdges = []
    dist = [-1, 0, 1]
    for dicts in TrajectoryPoints:
        chordEdges = []
        l = list(itt.product(dicts.values(), dicts.values()))
        for couple in l:
            (x1, y1), (x2, y2) = couple
            if (x1 - x2) in dist  and (y1 - y2) in dist:
                if not (((x1 - x2) == 1 and (y1 - y2) == -1) or ((x1 - x2) == -1 and (y1 - y2) == 1)) :
                    chordEdges.append(couple)
        TotalEdges.append(chordEdges)
    return TotalEdges

# %%
TrajectoryEdges = TrajectoryNoteEdges(trajectory.chordPositions, Tonnetz)

# %% [markdown]
# ### Let's plot that!

# %% [markdown]
# First just Points

# %%
# %matplotlib notebook

import numpy as np
import pylab as plt
from matplotlib import collections  as mc

fig, ax = plt.subplots()
    
for el in TrajectoryEdges:
    line = []
    line = mc.LineCollection(el, linewidths=0.3)
    ax.add_collection(line)
    ax.autoscale()
    ax.margins(0.1)

plt.grid()
plt.axis('equal')


plt.show()
# Out:
# <img src="data:image/png;base64,..." width="674.8444444444444">

# %% [markdown]
# ### Lets Find all the Edges by building a product on all points

# %% [markdown]
# Let's try graph libraries

# %%
import networkx as nx
G = nx.Graph()

# %%
def NotesToEdges(TrajectoryPoints, TrajectoryNoteEdges, Graph):
    listofPoints = []
    for i, dicts in enumerate(TrajectoryPoints):
        for el in dicts:
            Graph.add_node(dicts[el])
    for j in TrajectoryNoteEdges:
        Graph.add_edge(j[0], j[1])
    return Graph

# %%
newGraph = NotesToEdges(trajectory.chordPositions, TrajectoryEdges, G)
# %matplotlib notebook

nx.draw(newGraph)
plt.show()
# Out:
# <img src="data:image/png;base64,..." width="640">
