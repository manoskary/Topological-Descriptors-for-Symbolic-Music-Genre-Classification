# %% [markdown]
# # Creating Trajectory and Graph Objects, Store Local

# %% [markdown]
# In this Notebook we learn how to save our data as pickle files locally. This will help to create later on a CSV files with all the attributes we will need for prediction techniques. Remember we are saving objects so their size is considerable.

# %% [markdown]
# ### Import Files & Modules

# %%
from Tonnetz_Select import fromMidiToPCS as fmpc
from Tonnetz_Select import analysisFromCorpus
from TrajectoryCalculationsWithClass import NewTrajectory, TrajectoryLookBefore
from graph_creation import CreateGraph
from FirstNotePosition import PlaceFirstNote
from structural_functions import mergeDicts
from Compliance_Function import complianceFunction
import os
import pickle
from itertools import islice, groupby
from operator import itemgetter
import music21 as ms
import pretty_midi as ptm

# %% [markdown]
# Use pickle to Save Files with ".p" extension

# %%
def pickleSave(dictOfGraphs, Composer_Name) :
    completeName = "Comparison_Results/GraphObjects_new/"+ Composer_Name + ".p"
    with open(completeName, 'wb') as config_dictionary_file:
      # Step 3
      pickle.dump(dictOfGraphs, config_dictionary_file)

# %% [markdown]
# Functions to find the Midi attributes :

# %%
def findInstruments(file):
    instruments = []
    time_signatures = []
    s = ms.converter.parse(file)
    for element in s.recurse() :
        if 'TimeSignature' in element.classes :
            time_signatures.append(element.ratioString)
        if 'Instrument' in element.classes :
            x = str(element)
            if x != '' :
                if ': ' in x :
                    newstring = x.split(': ', -1)[1]
                    instruments.append(newstring)
                else :
                    instruments.append(x)
    time_signatures = list(map(itemgetter(0), groupby(time_signatures)))
    return instruments, time_signatures

# %%
def TempoAdd(directory):
    s = ptm.PrettyMIDI(directory)
    tempo = s.estimate_tempo()
    return int(tempo)

# %% [markdown]
# The following Definitions are defines in python files but we added some details (found in AutoHarmonic Analysis)

# %%
def GraphOfNewPiece(newPiece, directory):
    '''Build a graph Object from a midi file.'''
    # extract the directory and the file extension from the piece
    shortfilename = os.path.splitext(os.path.basename(newPiece))[0]
    # Choose from where to parse (directory, corpus)
    if directory == 'corpus':
        file = ms.corpus.parse(newPiece)
#         chordList, Tonnetz, connectivity = analysisFromCorpus(file)
        # apply full compliance function for corpus
            # finds chordList and 2 Tonnetze
        chordList, (Tonnetz1, Tonnetz2) = complianceFunction(file, "Corpus")
    # add the instruments
        instruments, time_signatures = findInstruments(newPiece)
        tempo = []
    else:
        if newPiece.endswith(".mid") or newPiece.endswith(".MID"):
            complete_name = directory + '/' + newPiece
#             chordList, Tonnetz, connectivity = fmpc(complete_name)
            # apply full compliance function for File
            chordList, (Tonnetz1, Tonnetz2) = complianceFunction(complete_name, "File")
        # add the instruments
            instruments, time_signatures = findInstruments(complete_name)
            tempo = TempoAdd(complete_name)
#   build 2 different trajectories on 2 different Tonnetze
    # First Tonnetz 2 Graph
    firstPoint1 = PlaceFirstNote(chordList, Tonnetz1)
    trajectory1 = NewTrajectory(chordList, Tonnetz1, firstPoint1)
    trajectory1.addType('Trajectory Tonnetz 1')
    trajectory1.addInstruments(instruments)
    trajectory1.addTime_signatures(time_signatures)
    trajectory1.addTempo(tempo)
    graph1 = CreateGraph(trajectory1)
    graph1.addName(shortfilename)
    
    # Second Tonnetz 2 Graph
    firstPoint2 = PlaceFirstNote(chordList, Tonnetz2)
    trajectory2 = NewTrajectory(chordList, Tonnetz2, firstPoint2)
    trajectory2.addType('Trajectory Tonnetz 2')
    trajectory2.addInstruments(instruments)
    trajectory2.addTime_signatures(time_signatures)
    trajectory2.addTempo(tempo)
    graph2 = CreateGraph(trajectory2)
    graph2.addName(shortfilename)
    
    return graph1, graph2

# %%
def GetWorksByComposer(composerName, composer, style):
    listOfGraphs = []
#     composer, style, harmony = inputQuestions()
    listofWorks = ms.corpus.getComposer(composerName)
    if len(listofWorks) > 60 :
        listofWorks = list(islice(listofWorks, 60))
    if len(listofWorks) > 0:
        for piece in listofWorks:
            try:
                print("Building Trajectory for ", piece)
                graph1, graph2 = GraphOfNewPiece(piece, 'corpus')
#                 addingLabels(composer, style, harmony, graph)
                graph1.addStyle(style)
                graph1.addComposer(composer)
                graph2.addStyle(style)
                graph2.addComposer(composer)
                listOfGraphs.append([graph1, graph2])
            except BaseException:
                print("--> Cannot build Trajectory for ", piece)
    return listOfGraphs

# %%
def GetWorksByDirectory(directory, composer, style):
    listOfGraphs = []
#     composer, style, harmony = inputQuestions()
    for file in os.listdir(directory):
        if file.endswith(".mid") or file.endswith(
                ".MID") or file.endswith(".mxl") or file.endswith(".xml"):
            try:
                print("Building Trajectory for ", file)
                graphFut, graphRec = GraphOfNewPiece(file, directory)
#                 addingLabels(composer, style, harmony, graph)
                graph1.addStyle(style)
                graph1.addComposer(composer)
                graph2.addStyle(style)
                graph2.addComposer(composer)
                listOfGraphs.append([graph1, graph2])
            except BaseException:
                print("--> Cannot build Trajectory for ", file)
    return listOfGraphs

# %% [markdown]
# ### Begin Process (define Directory, composer and style)

# %%
GraphOfNewPiece("haydn_cmaj.mid", "Midi_Files")
# Out:
# 537
# (<GraphClass.GraphClass at 0x5f6f650>, <GraphClass.GraphClass at 0x9966d30>)

# %%
mozart_quartets = GetWorksByDirectory('Midi_files/mozart_string_quartets', 'mozart', 'classical')
# Out:
# Building Trajectory for  k080-01.mid
# 1034
# --> Cannot build Trajectory for  k080-01.mid
# Building Trajectory for  k080-02.mid
# 1146
# --> Cannot build Trajectory for  k080-02.mid
# Building Trajectory for  k080-03.mid
# 470
# --> Cannot build Trajectory for  k080-03.mid
# Building Trajectory for  k080-04.mid
# 438
# --> Cannot build Trajectory for  k080-04.mid
# Building Trajectory for  k155-01.mid
# 933
# --> Cannot build Trajectory for  k155-01.mid
# Building Trajectory for  k155-02.mid
# 690
# --> Cannot build Trajectory for  k155-02.mid
# Building Trajectory for  k155-03.mid
# 474
# --> Cannot build Trajectory for  k155-03.mid
# Building Trajectory for  k156-01.mid
# 1182
# --> Cannot build Trajectory for  k156-01.mid
# Building Trajectory for  k156-02.mid
# --> Cannot build Trajectory for  k156-02.mid
# Building Trajectory for  k156-03.mid
# --> Cannot build Trajectory for  k156-03.mid
# Building Trajectory for  k157-01.mid
# --> Cannot build Trajectory for  k157-01.mid
# Building Trajectory for  k157-02.mid
# --> Cannot build Trajectory for  k157-02.mid
# Building Trajectory for  k157-03.mid
# --> Cannot build Trajectory for  k157-03.mid
# Building Trajectory for  k158-01.mid
# --> Cannot build Trajectory for  k158-01.mid
# Building Trajectory for  k158-03.mid
# 588
# --> Cannot build Trajectory for  k158-03.mid
# Building Trajectory for  k160-02.mid
# 600
# --> Cannot build Trajectory for  k160-02.mid
# Building Trajectory for  k160-03.mid
# 1226
# --> Cannot build Trajectory for  k160-03.mid
# Building Trajectory for  k168-01.mid
# 656
# --> Cannot build Trajectory for  k168-01.mid
# Building Trajectory for  k168-02.mid
# 198
# --> Cannot build Trajectory for  k168-02.mid
# Building Trajectory for  k168-03.mid
# 150
# --> Cannot build Trajectory for  k168-03.mid
# Building Trajectory for  k169-01.mid
# 678
# --> Cannot build Trajectory for  k169-01.mid
# Building Trajectory for  k169-03.mid
# 211
# --> Cannot build Trajectory for  k169-03.mid
# Building Trajectory for  k169-04.mid
# 357
# --> Cannot build Trajectory for  k169-04.mid
# Building Trajectory for  k170-02.mid
# 187
# --> Cannot build Trajectory for  k170-02.mid
# Building Trajectory for  k170-03.mid
# --> Cannot build Trajectory for  k170-03.mid
# Building Trajectory for  k170-04.mid
# --> Cannot build Trajectory for  k170-04.mid
# Building Trajectory for  k171-01.mid
# --> Cannot build Trajectory for  k171-01.mid
# Building Trajectory for  k171-02.mid
# --> Cannot build Trajectory for  k171-02.mid
# Building Trajectory for  k171-03.mid
# --> Cannot build Trajectory for  k171-03.mid
# Building Trajectory for  k171-04.mid
# --> Cannot build Trajectory for  k171-04.mid
# Building Trajectory for  k172-01.mid
# --> Cannot build Trajectory for  k172-01.mid
# Building Trajectory for  k172-02.mid
# --> Cannot build Trajectory for  k172-02.mid
# Building Trajectory for  k172-04.mid
# --> Cannot build Trajectory for  k172-04.mid
# Building Trajectory for  k173-01.mid
# --> Cannot build Trajectory for  k173-01.mid
# Building Trajectory for  k173-03.mid
# --> Cannot build Trajectory for  k173-03.mid
# Building Trajectory for  k173-04.mid
# --> Cannot build Trajectory for  k173-04.mid
# Building Trajectory for  k285-01.mid
# --> Cannot build Trajectory for  k285-01.mid
# Building Trajectory for  k285-02.mid
# --> Cannot build Trajectory for  k285-02.mid
# Building Trajectory for  k285-03.mid
# --> Cannot build Trajectory for  k285-03.mid
# Building Trajectory for  k298-01.mid
# --> Cannot build Trajectory for  k298-01.mid
# Building Trajectory for  k298-02.mid
# --> Cannot build Trajectory for  k298-02.mid
# Building Trajectory for  k298-03.mid
# --> Cannot build Trajectory for  k298-03.mid
# Building Trajectory for  k370-01.mid
# --> Cannot build Trajectory for  k370-01.mid
# Building Trajectory for  k370-02.mid
# --> Cannot build Trajectory for  k370-02.mid
# Building Trajectory for  k387-01.mid
# --> Cannot build Trajectory for  k387-01.mid
# Building Trajectory for  k387-02.mid
# --> Cannot build Trajectory for  k387-02.mid
# Building Trajectory for  k387-03.mid
# --> Cannot build Trajectory for  k387-03.mid
# Building Trajectory for  k387-04.mid
# --> Cannot build Trajectory for  k387-04.mid
# Building Trajectory for  k421-01.mid
# --> Cannot build Trajectory for  k421-01.mid
# Building Trajectory for  k421-02.mid
# --> Cannot build Trajectory for  k421-02.mid
# Building Trajectory for  k421-03.mid
# --> Cannot build Trajectory for  k421-03.mid
# Building Trajectory for  k421-04.mid
# --> Cannot build Trajectory for  k421-04.mid
# Building Trajectory for  k428-01.mid
# --> Cannot build Trajectory for  k428-01.mid
# Building Trajectory for  k428-02.mid
# --> Cannot build Trajectory for  k428-02.mid
# Building Trajectory for  k428-03.mid
# --> Cannot build Trajectory for  k428-03.mid
# Building Trajectory for  k458-01.mid
# --> Cannot build Trajectory for  k458-01.mid
# Building Trajectory for  k458-02.mid
# --> Cannot build Trajectory for  k458-02.mid
# Building Trajectory for  k458-03.mid
# --> Cannot build Trajectory for  k458-03.mid
# Building Trajectory for  k464-02.mid
# --> Cannot build Trajectory for  k464-02.mid
# Building Trajectory for  k464-03.mid
# --> Cannot build Trajectory for  k464-03.mid
# Building Trajectory for  k464-04.mid
# --> Cannot build Trajectory for  k464-04.mid
# Building Trajectory for  k465-01.mid
# --> Cannot build Trajectory for  k465-01.mid
# Building Trajectory for  k465-02.mid
# --> Cannot build Trajectory for  k465-02.mid
# Building Trajectory for  k465-03.mid
# --> Cannot build Trajectory for  k465-03.mid
# Building Trajectory for  k465-04.mid
# --> Cannot build Trajectory for  k465-04.mid
# Building Trajectory for  k499-01.mid
# --> Cannot build Trajectory for  k499-01.mid
# Building Trajectory for  k499-03.mid
# --> Cannot build Trajectory for  k499-03.mid
# Building Trajectory for  k499-04.mid
# --> Cannot build Trajectory for  k499-04.mid
# Building Trajectory for  k575-02.mid
# --> Cannot build Trajectory for  k575-02.mid
# Building Trajectory for  k575-03.mid
# --> Cannot build Trajectory for  k575-03.mid
# Building Trajectory for  k589-01.mid
# --> Cannot build Trajectory for  k589-01.mid
# Building Trajectory for  k589-03.mid
# --> Cannot build Trajectory for  k589-03.mid
# Building Trajectory for  k589-04.mid
# --> Cannot build Trajectory for  k589-04.mid
# Building Trajectory for  k590-01.mid
# --> Cannot build Trajectory for  k590-01.mid
# Building Trajectory for  k590-02.mid
# --> Cannot build Trajectory for  k590-02.mid
# Building Trajectory for  k590-03.mid
# --> Cannot build Trajectory for  k590-03.mid
# Building Trajectory for  k590-04.mid
# --> Cannot build Trajectory for  k590-04.mid

# %%
haydn_quartets = GetWorksByDirectory('Midi_files/haydn_string_quartets', 'haydn', 'classical')
# Out:
# Building Trajectory for  op01n0-01.mid
# --> Cannot build Trajectory for  op01n0-01.mid
# Building Trajectory for  op01n0-02.mid
# --> Cannot build Trajectory for  op01n0-02.mid
# Building Trajectory for  op01n0-03.mid
# --> Cannot build Trajectory for  op01n0-03.mid
# Building Trajectory for  op01n0-05.mid
# --> Cannot build Trajectory for  op01n0-05.mid
# Building Trajectory for  op01n1-01.mid
# --> Cannot build Trajectory for  op01n1-01.mid
# Building Trajectory for  op01n1-02.mid
# --> Cannot build Trajectory for  op01n1-02.mid
# Building Trajectory for  op01n1-03.mid
# --> Cannot build Trajectory for  op01n1-03.mid
# Building Trajectory for  op01n1-04.mid
# --> Cannot build Trajectory for  op01n1-04.mid
# Building Trajectory for  op01n1-05.mid
# --> Cannot build Trajectory for  op01n1-05.mid
# Building Trajectory for  op01n2-01.mid
# --> Cannot build Trajectory for  op01n2-01.mid
# Building Trajectory for  op01n2-02.mid
# --> Cannot build Trajectory for  op01n2-02.mid
# Building Trajectory for  op01n2-03.mid
# --> Cannot build Trajectory for  op01n2-03.mid
# Building Trajectory for  op01n2-04.mid
# --> Cannot build Trajectory for  op01n2-04.mid
# Building Trajectory for  op01n2-05.mid
# --> Cannot build Trajectory for  op01n2-05.mid
# Building Trajectory for  op01n3-01.mid
# --> Cannot build Trajectory for  op01n3-01.mid
# Building Trajectory for  op01n3-03.mid
# --> Cannot build Trajectory for  op01n3-03.mid
# Building Trajectory for  op01n3-04.mid
# --> Cannot build Trajectory for  op01n3-04.mid
# Building Trajectory for  op01n3-05.mid
# --> Cannot build Trajectory for  op01n3-05.mid
# Building Trajectory for  op01n4-01.mid
# --> Cannot build Trajectory for  op01n4-01.mid
# Building Trajectory for  op01n4-02.mid
# --> Cannot build Trajectory for  op01n4-02.mid
# Building Trajectory for  op01n4-03.mid
# --> Cannot build Trajectory for  op01n4-03.mid
# Building Trajectory for  op01n4-04.mid
# --> Cannot build Trajectory for  op01n4-04.mid
# Building Trajectory for  op01n4-05.mid
# --> Cannot build Trajectory for  op01n4-05.mid
# Building Trajectory for  op01n6-01.mid
# --> Cannot build Trajectory for  op01n6-01.mid
# Building Trajectory for  op01n6-02.mid
# --> Cannot build Trajectory for  op01n6-02.mid
# Building Trajectory for  op01n6-04.mid
# --> Cannot build Trajectory for  op01n6-04.mid
# Building Trajectory for  op01n6-05.mid
# --> Cannot build Trajectory for  op01n6-05.mid
# Building Trajectory for  op09n2-01.mid
# --> Cannot build Trajectory for  op09n2-01.mid
# Building Trajectory for  op09n2-02.mid
# --> Cannot build Trajectory for  op09n2-02.mid
# Building Trajectory for  op09n2-03.mid
# --> Cannot build Trajectory for  op09n2-03.mid
# Building Trajectory for  op09n2-04.mid
# --> Cannot build Trajectory for  op09n2-04.mid
# Building Trajectory for  op17n2-01.mid
# --> Cannot build Trajectory for  op17n2-01.mid
# Building Trajectory for  op17n2-02.mid
# --> Cannot build Trajectory for  op17n2-02.mid
# Building Trajectory for  op17n2-03.mid
# --> Cannot build Trajectory for  op17n2-03.mid
# Building Trajectory for  op17n2-04.mid
# --> Cannot build Trajectory for  op17n2-04.mid
# Building Trajectory for  op17n3-01.mid
# --> Cannot build Trajectory for  op17n3-01.mid
# Building Trajectory for  op17n3-02.mid
# 221
# --> Cannot build Trajectory for  op17n3-02.mid
# Building Trajectory for  op17n3-03.mid
# --> Cannot build Trajectory for  op17n3-03.mid
# Building Trajectory for  op17n3-04.mid
# --> Cannot build Trajectory for  op17n3-04.mid
# Building Trajectory for  op17n5-01.mid
# --> Cannot build Trajectory for  op17n5-01.mid
# Building Trajectory for  op17n5-02.mid
# --> Cannot build Trajectory for  op17n5-02.mid
# Building Trajectory for  op17n5-03.mid
# --> Cannot build Trajectory for  op17n5-03.mid
# Building Trajectory for  op17n5-04.mid
# --> Cannot build Trajectory for  op17n5-04.mid
# Building Trajectory for  op17n6-01.mid
# --> Cannot build Trajectory for  op17n6-01.mid
# Building Trajectory for  op17n6-02.mid
# --> Cannot build Trajectory for  op17n6-02.mid
# Building Trajectory for  op17n6-03.mid
# --> Cannot build Trajectory for  op17n6-03.mid
# Building Trajectory for  op17n6-04.mid
# --> Cannot build Trajectory for  op17n6-04.mid
# Building Trajectory for  op20n1-01.mid
# --> Cannot build Trajectory for  op20n1-01.mid
# Building Trajectory for  op20n1-02.mid
# --> Cannot build Trajectory for  op20n1-02.mid
# Building Trajectory for  op20n1-04.mid
# 491
# --> Cannot build Trajectory for  op20n1-04.mid
# Building Trajectory for  op20n2-01.mid
# --> Cannot build Trajectory for  op20n2-01.mid
# Building Trajectory for  op20n2-03.mid
# --> Cannot build Trajectory for  op20n2-03.mid
# Building Trajectory for  op20n2-04.mid
# --> Cannot build Trajectory for  op20n2-04.mid
# Building Trajectory for  op20n3-02.mid
# --> Cannot build Trajectory for  op20n3-02.mid
# Building Trajectory for  op20n3-03.mid
# --> Cannot build Trajectory for  op20n3-03.mid
# Building Trajectory for  op20n3-04.mid
# --> Cannot build Trajectory for  op20n3-04.mid
# Building Trajectory for  op20n4-03.mid
# 147
# --> Cannot build Trajectory for  op20n4-03.mid
# Building Trajectory for  op20n4-04.mid
# --> Cannot build Trajectory for  op20n4-04.mid
# Building Trajectory for  op20n5-01.mid
# --> Cannot build Trajectory for  op20n5-01.mid
# Building Trajectory for  op20n5-02.mid
# --> Cannot build Trajectory for  op20n5-02.mid
# Building Trajectory for  op20n5-03.mid
# --> Cannot build Trajectory for  op20n5-03.mid
# Building Trajectory for  op20n5-04.mid
# --> Cannot build Trajectory for  op20n5-04.mid
# Building Trajectory for  op20n6-01.mid
# --> Cannot build Trajectory for  op20n6-01.mid
# Building Trajectory for  op20n6-02.mid
# --> Cannot build Trajectory for  op20n6-02.mid
# Building Trajectory for  op20n6-03.mid
# 133
# --> Cannot build Trajectory for  op20n6-03.mid
# Building Trajectory for  op20n6-04.mid
# --> Cannot build Trajectory for  op20n6-04.mid
# Building Trajectory for  op33n1-01.mid
# --> Cannot build Trajectory for  op33n1-01.mid
# Building Trajectory for  op33n1-02.mid
# 155
# --> Cannot build Trajectory for  op33n1-02.mid
# Building Trajectory for  op33n1-03.mid
# --> Cannot build Trajectory for  op33n1-03.mid
# Building Trajectory for  op33n1-04.mid
# 704
# --> Cannot build Trajectory for  op33n1-04.mid
# Building Trajectory for  op33n2-01.mid
# --> Cannot build Trajectory for  op33n2-01.mid
# Building Trajectory for  op33n2-02.mid
# --> Cannot build Trajectory for  op33n2-02.mid
# Building Trajectory for  op33n2-03.mid
# --> Cannot build Trajectory for  op33n2-03.mid
# Building Trajectory for  op33n3-01.mid
# --> Cannot build Trajectory for  op33n3-01.mid
# Building Trajectory for  op33n3-02.mid
# 160
# --> Cannot build Trajectory for  op33n3-02.mid
# Building Trajectory for  op33n3-03.mid
# --> Cannot build Trajectory for  op33n3-03.mid
# Building Trajectory for  op33n3-04.mid
# --> Cannot build Trajectory for  op33n3-04.mid
# Building Trajectory for  op33n4-01.mid
# --> Cannot build Trajectory for  op33n4-01.mid
# Building Trajectory for  op33n4-02.mid
# 142
# --> Cannot build Trajectory for  op33n4-02.mid
# Building Trajectory for  op33n4-03.mid
# --> Cannot build Trajectory for  op33n4-03.mid
# Building Trajectory for  op33n4-04.mid
# --> Cannot build Trajectory for  op33n4-04.mid
# Building Trajectory for  op33n5-01.mid
# --> Cannot build Trajectory for  op33n5-01.mid
# Building Trajectory for  op33n5-02.mid
# --> Cannot build Trajectory for  op33n5-02.mid
# Building Trajectory for  op33n5-03.mid
# 227
# --> Cannot build Trajectory for  op33n5-03.mid
# Building Trajectory for  op33n5-04.mid
# --> Cannot build Trajectory for  op33n5-04.mid
# Building Trajectory for  op33n6-01.mid
# --> Cannot build Trajectory for  op33n6-01.mid
# Building Trajectory for  op33n6-02.mid
# --> Cannot build Trajectory for  op33n6-02.mid
# Building Trajectory for  op33n6-03.mid
# 169
# --> Cannot build Trajectory for  op33n6-03.mid
# Building Trajectory for  op33n6-04.mid
# --> Cannot build Trajectory for  op33n6-04.mid
# Building Trajectory for  op42-01.mid
# --> Cannot build Trajectory for  op42-01.mid
# Building Trajectory for  op42-02.mid
# 172
# --> Cannot build Trajectory for  op42-02.mid
# Building Trajectory for  op42-03.mid
# --> Cannot build Trajectory for  op42-03.mid
# Building Trajectory for  op42-04.mid
# --> Cannot build Trajectory for  op42-04.mid
# Building Trajectory for  op50n1-01.mid
# --> Cannot build Trajectory for  op50n1-01.mid
# Building Trajectory for  op50n1-02.mid
# --> Cannot build Trajectory for  op50n1-02.mid
# Building Trajectory for  op50n1-03.mid
# 182
# --> Cannot build Trajectory for  op50n1-03.mid
# Building Trajectory for  op50n1-04.mid
# --> Cannot build Trajectory for  op50n1-04.mid
# Building Trajectory for  op50n2-01.mid
# --> Cannot build Trajectory for  op50n2-01.mid
# Building Trajectory for  op50n2-02.mid
# --> Cannot build Trajectory for  op50n2-02.mid
# Building Trajectory for  op50n2-03.mid
# --> Cannot build Trajectory for  op50n2-03.mid
# Building Trajectory for  op50n2-04.mid
# --> Cannot build Trajectory for  op50n2-04.mid
# Building Trajectory for  op50n3-01.mid
# --> Cannot build Trajectory for  op50n3-01.mid
# Building Trajectory for  op50n3-03.mid
# --> Cannot build Trajectory for  op50n3-03.mid
# Building Trajectory for  op50n3-04.mid
# --> Cannot build Trajectory for  op50n3-04.mid
# Building Trajectory for  op50n4-01.mid
# --> Cannot build Trajectory for  op50n4-01.mid
# Building Trajectory for  op50n4-03.mid
# 268
# --> Cannot build Trajectory for  op50n4-03.mid
# Building Trajectory for  op50n4-04.mid
# --> Cannot build Trajectory for  op50n4-04.mid
# Building Trajectory for  op50n6-01.mid
# --> Cannot build Trajectory for  op50n6-01.mid
# Building Trajectory for  op50n6-02.mid
# --> Cannot build Trajectory for  op50n6-02.mid
# Building Trajectory for  op50n6-03.mid
# 245
# --> Cannot build Trajectory for  op50n6-03.mid
# Building Trajectory for  op50n6-04.mid
# --> Cannot build Trajectory for  op50n6-04.mid
# Building Trajectory for  op54n1-01.mid
# --> Cannot build Trajectory for  op54n1-01.mid
# Building Trajectory for  op54n1-02.mid
# --> Cannot build Trajectory for  op54n1-02.mid
# Building Trajectory for  op54n1-03.mid
# 280
# --> Cannot build Trajectory for  op54n1-03.mid
# Building Trajectory for  op54n1-04.mid
# --> Cannot build Trajectory for  op54n1-04.mid
# Building Trajectory for  op54n2-01.mid
# --> Cannot build Trajectory for  op54n2-01.mid
# Building Trajectory for  op54n2-03.mid
# --> Cannot build Trajectory for  op54n2-03.mid
# Building Trajectory for  op54n2-04.mid
# --> Cannot build Trajectory for  op54n2-04.mid
# Building Trajectory for  op54n3-01.mid
# --> Cannot build Trajectory for  op54n3-01.mid
# Building Trajectory for  op54n3-02.mid
# --> Cannot build Trajectory for  op54n3-02.mid
# Building Trajectory for  op54n3-03.mid
# 253
# --> Cannot build Trajectory for  op54n3-03.mid
# Building Trajectory for  op54n3-04.mid
# --> Cannot build Trajectory for  op54n3-04.mid
# Building Trajectory for  op55n1-03.mid
# --> Cannot build Trajectory for  op55n1-03.mid
# Building Trajectory for  op55n1-04.mid
# --> Cannot build Trajectory for  op55n1-04.mid
# Building Trajectory for  op55n2-01.mid
# --> Cannot build Trajectory for  op55n2-01.mid
# Building Trajectory for  op55n2-02.mid
# --> Cannot build Trajectory for  op55n2-02.mid
# Building Trajectory for  op55n2-03.mid
# 307
# --> Cannot build Trajectory for  op55n2-03.mid
# Building Trajectory for  op55n2-04.mid
# --> Cannot build Trajectory for  op55n2-04.mid

# %%
pickleSave(mozart_quartets, 'mozart_quartets')
pickleSave(haydn_quartets, 'haydn_quartets')

# %%
bach = GetWorksByComposer('bach', 'bach', 'barok')
# Out:
# Building Trajectory for  C:\Users\melki\AppData\Local\Programs\Python\Python36-32\Lib\site-packages\music21\corpus\bach\bwv1.6.mxl
# 124
# Building Trajectory for  C:\Users\melki\AppData\Local\Programs\Python\Python36-32\Lib\site-packages\music21\corpus\bach\bwv10.7.mxl
# 61
# Building Trajectory for  C:\Users\melki\AppData\Local\Programs\Python\Python36-32\Lib\site-packages\music21\corpus\bach\bwv101.7.mxl
# 61
# Building Trajectory for  C:\Users\melki\AppData\Local\Programs\Python\Python36-32\Lib\site-packages\music21\corpus\bach\bwv102.7.mxl
# 71
# Building Trajectory for  C:\Users\melki\AppData\Local\Programs\Python\Python36-32\Lib\site-packages\music21\corpus\bach\bwv103.6.mxl
# 84
# Building Trajectory for  C:\Users\melki\AppData\Local\Programs\Python\Python36-32\Lib\site-packages\music21\corpus\bach\bwv104.6.mxl
# 67
# Building Trajectory for  C:\Users\melki\AppData\Local\Programs\Python\Python36-32\Lib\site-packages\music21\corpus\bach\bwv108.6.mxl
# 91
# Building Trajectory for  C:\Users\melki\AppData\Local\Programs\Python\Python36-32\Lib\site-packages\music21\corpus\bach\bwv11.6.mxl
# 107
# Building Trajectory for  C:\Users\melki\AppData\Local\Programs\Python\Python36-32\Lib\site-packages\music21\corpus\bach\bwv110.7.mxl
# 66
# Building Trajectory for  C:\Users\melki\AppData\Local\Programs\Python\Python36-32\Lib\site-packages\music21\corpus\bach\bwv111.6.mxl
# 120
# Building Trajectory for  C:\Users\melki\AppData\Local\Programs\Python\Python36-32\Lib\site-packages\music21\corpus\bach\bwv112.5-sc.mxl
# 73
# Building Trajectory for  C:\Users\melki\AppData\Local\Programs\Python\Python36-32\Lib\site-packages\music21\corpus\bach\bwv112.5.mxl
# 94
# Building Trajectory for  C:\Users\melki\AppData\Local\Programs\Python\Python36-32\Lib\site-packages\music21\corpus\bach\bwv113.8.mxl
# 70
# Building Trajectory for  C:\Users\melki\AppData\Local\Programs\Python\Python36-32\Lib\site-packages\music21\corpus\bach\bwv114.7.mxl
# 70
# Building Trajectory for  C:\Users\melki\AppData\Local\Programs\Python\Python36-32\Lib\site-packages\music21\corpus\bach\bwv115.6.mxl
# 55
# Building Trajectory for  C:\Users\melki\AppData\Local\Programs\Python\Python36-32\Lib\site-packages\music21\corpus\bach\bwv116.6.mxl
# 69
# Building Trajectory for  C:\Users\melki\AppData\Local\Programs\Python\Python36-32\Lib\site-packages\music21\corpus\bach\bwv117.4.mxl
# 68
# Building Trajectory for  C:\Users\melki\AppData\Local\Programs\Python\Python36-32\Lib\site-packages\music21\corpus\bach\bwv119.9.mxl
# 59
# Building Trajectory for  C:\Users\melki\AppData\Local\Programs\Python\Python36-32\Lib\site-packages\music21\corpus\bach\bwv12.7.mxl
# 83
# Building Trajectory for  C:\Users\melki\AppData\Local\Programs\Python\Python36-32\Lib\site-packages\music21\corpus\bach\bwv120.6.mxl
# 89
# Building Trajectory for  C:\Users\melki\AppData\Local\Programs\Python\Python36-32\Lib\site-packages\music21\corpus\bach\bwv120.8-a.mxl
# 94
# Building Trajectory for  C:\Users\melki\AppData\Local\Programs\Python\Python36-32\Lib\site-packages\music21\corpus\bach\bwv121.6.mxl
# 96
# Building Trajectory for  C:\Users\melki\AppData\Local\Programs\Python\Python36-32\Lib\site-packages\music21\corpus\bach\bwv122.6.mxl
# 45
# Building Trajectory for  C:\Users\melki\AppData\Local\Programs\Python\Python36-32\Lib\site-packages\music21\corpus\bach\bwv123.6.mxl
# 50
# Building Trajectory for  C:\Users\melki\AppData\Local\Programs\Python\Python36-32\Lib\site-packages\music21\corpus\bach\bwv124.6.mxl
# 87
# Building Trajectory for  C:\Users\melki\AppData\Local\Programs\Python\Python36-32\Lib\site-packages\music21\corpus\bach\bwv125.6.mxl
# 68
# Building Trajectory for  C:\Users\melki\AppData\Local\Programs\Python\Python36-32\Lib\site-packages\music21\corpus\bach\bwv126.6.mxl
# 166
# Building Trajectory for  C:\Users\melki\AppData\Local\Programs\Python\Python36-32\Lib\site-packages\music21\corpus\bach\bwv127.5.mxl
# 77
# Building Trajectory for  C:\Users\melki\AppData\Local\Programs\Python\Python36-32\Lib\site-packages\music21\corpus\bach\bwv128.5.mxl
# 88
# Building Trajectory for  C:\Users\melki\AppData\Local\Programs\Python\Python36-32\Lib\site-packages\music21\corpus\bach\bwv13.6.mxl
# 64
# Building Trajectory for  C:\Users\melki\AppData\Local\Programs\Python\Python36-32\Lib\site-packages\music21\corpus\bach\bwv130.6.mxl
# 78
# Building Trajectory for  C:\Users\melki\AppData\Local\Programs\Python\Python36-32\Lib\site-packages\music21\corpus\bach\bwv133.6.mxl
# 55
# Building Trajectory for  C:\Users\melki\AppData\Local\Programs\Python\Python36-32\Lib\site-packages\music21\corpus\bach\bwv135.6.mxl
# 91
# Building Trajectory for  C:\Users\melki\AppData\Local\Programs\Python\Python36-32\Lib\site-packages\music21\corpus\bach\bwv136.6.mxl
# 70
# Building Trajectory for  C:\Users\melki\AppData\Local\Programs\Python\Python36-32\Lib\site-packages\music21\corpus\bach\bwv137.5.mxl
# 66
# Building Trajectory for  C:\Users\melki\AppData\Local\Programs\Python\Python36-32\Lib\site-packages\music21\corpus\bach\bwv139.6.mxl
# 70
# Building Trajectory for  C:\Users\melki\AppData\Local\Programs\Python\Python36-32\Lib\site-packages\music21\corpus\bach\bwv14.5.mxl
# 76
# Building Trajectory for  C:\Users\melki\AppData\Local\Programs\Python\Python36-32\Lib\site-packages\music21\corpus\bach\bwv140.7.mxl
# 91
# Building Trajectory for  C:\Users\melki\AppData\Local\Programs\Python\Python36-32\Lib\site-packages\music21\corpus\bach\bwv144.3.mxl
# 63
# Building Trajectory for  C:\Users\melki\AppData\Local\Programs\Python\Python36-32\Lib\site-packages\music21\corpus\bach\bwv144.6.mxl
# 85
# Building Trajectory for  C:\Users\melki\AppData\Local\Programs\Python\Python36-32\Lib\site-packages\music21\corpus\bach\bwv145-a.mxl
# 74
# Building Trajectory for  C:\Users\melki\AppData\Local\Programs\Python\Python36-32\Lib\site-packages\music21\corpus\bach\bwv145.5.mxl
# 57
# Building Trajectory for  C:\Users\melki\AppData\Local\Programs\Python\Python36-32\Lib\site-packages\music21\corpus\bach\bwv146.8.mxl
# 92
# Building Trajectory for  C:\Users\melki\AppData\Local\Programs\Python\Python36-32\Lib\site-packages\music21\corpus\bach\bwv148.6.mxl
# 69
# Building Trajectory for  C:\Users\melki\AppData\Local\Programs\Python\Python36-32\Lib\site-packages\music21\corpus\bach\bwv149.7.mxl
# 180
# Building Trajectory for  C:\Users\melki\AppData\Local\Programs\Python\Python36-32\Lib\site-packages\music21\corpus\bach\bwv151.5.mxl
# 53
# Building Trajectory for  C:\Users\melki\AppData\Local\Programs\Python\Python36-32\Lib\site-packages\music21\corpus\bach\bwv153.1.mxl
# 63
# Building Trajectory for  C:\Users\melki\AppData\Local\Programs\Python\Python36-32\Lib\site-packages\music21\corpus\bach\bwv153.5.mxl
# 54
# Building Trajectory for  C:\Users\melki\AppData\Local\Programs\Python\Python36-32\Lib\site-packages\music21\corpus\bach\bwv153.9.mxl
# 36
# Building Trajectory for  C:\Users\melki\AppData\Local\Programs\Python\Python36-32\Lib\site-packages\music21\corpus\bach\bwv154.3.mxl
# 62
# Building Trajectory for  C:\Users\melki\AppData\Local\Programs\Python\Python36-32\Lib\site-packages\music21\corpus\bach\bwv154.8.mxl
# 84
# Building Trajectory for  C:\Users\melki\AppData\Local\Programs\Python\Python36-32\Lib\site-packages\music21\corpus\bach\bwv155.5.mxl
# 76
# Building Trajectory for  C:\Users\melki\AppData\Local\Programs\Python\Python36-32\Lib\site-packages\music21\corpus\bach\bwv156.6.mxl
# 64
# Building Trajectory for  C:\Users\melki\AppData\Local\Programs\Python\Python36-32\Lib\site-packages\music21\corpus\bach\bwv157.5.mxl
# 81
# Building Trajectory for  C:\Users\melki\AppData\Local\Programs\Python\Python36-32\Lib\site-packages\music21\corpus\bach\bwv158.4.mxl
# 83
# Building Trajectory for  C:\Users\melki\AppData\Local\Programs\Python\Python36-32\Lib\site-packages\music21\corpus\bach\bwv159.5.mxl
# 94
# Building Trajectory for  C:\Users\melki\AppData\Local\Programs\Python\Python36-32\Lib\site-packages\music21\corpus\bach\bwv16.6.mxl
# 63
# Building Trajectory for  C:\Users\melki\AppData\Local\Programs\Python\Python36-32\Lib\site-packages\music21\corpus\bach\bwv161.6.mxl
# 153
# Building Trajectory for  C:\Users\melki\AppData\Local\Programs\Python\Python36-32\Lib\site-packages\music21\corpus\bach\bwv162.6-lpz.mxl
# 97
# Building Trajectory for  C:\Users\melki\AppData\Local\Programs\Python\Python36-32\Lib\site-packages\music21\corpus\bach\bwv164.6.mxl
# 55

# %%
beethoven = GetWorksByDirectory('Midi_files/Classical/Beethoven', 'beethoven', 'classical')
beethovenCorpus = GetWorksByComposer('beethoven', 'beethoven', 'classical')
# Out:
# Building Trajectory for  Cnpia523.mid
# 3793
# Building Trajectory for  Concvi1.mid
# 5604
# Building Trajectory for  Concvi23.mid
# 3140
# Building Trajectory for  Coriolan.mid
# 1890
# Building Trajectory for  Leonore1.mid
# 2331
# Building Trajectory for  Leonore2.mid
# 3357
# Building Trajectory for  Leonore3.mid
# 3696
# [11, 8, 4] dict_items([(11, (104, 105)), (4, (103, 104))]) (104, 105) 4 3 2
# --> Cannot build Trajectory for  Leonore3.mid
# Building Trajectory for  String Quartet n1 op18 1mov.mid
# 2612
# Building Trajectory for  String Quartet n1 op18 2mov.mid
# 1238
# Building Trajectory for  String Quartet n1 op18 3mov.mid
# 1518
# Building Trajectory for  String Quartet n1 op18 4mov.mid
# 2640
# [5, 4] dict_items([(5, (1, 1))]) (1, 1) 3 2 1
# --> Cannot build Trajectory for  String Quartet n1 op18 4mov.mid
# Building Trajectory for  String Quartet n16 op135 1mov.mid
# 1499
# [3, 8] dict_items([(3, (105, 105))]) (105, 105) 3 2 1
# --> Cannot build Trajectory for  String Quartet n16 op135 1mov.mid
# Building Trajectory for  String Quartet n16 op135 2mov.mid
# 1521
# [1, 8] dict_items([(1, (103, 103))]) (103, 103) 3 2 1
# --> Cannot build Trajectory for  String Quartet n16 op135 2mov.mid
# Building Trajectory for  String Quartet n16 op135 3mov.mid
# 382
# Building Trajectory for  String Quartet n16 op135 4mov.mid
# --> Cannot build Trajectory for  String Quartet n16 op135 4mov.mid
# Building Trajectory for  String Quartet n2 op18 n2 1mov.mid
# 1963
# Building Trajectory for  String Quartet n2 op18 n2 3mov.mid
# 1651
# Building Trajectory for  String Quartet n2 op18 n2 4mov.mid
# 1796
# Building Trajectory for  String_Quartet_n2_op18_2mov.mid
# --> Cannot build Trajectory for  String_Quartet_n2_op18_2mov.mid
# Building Trajectory for  Symphonie1_Opus21_Mvt1.mid
# 1973
# Building Trajectory for  Symphonie1_Opus21_Mvt2.mid
# 1139
# Building Trajectory for  Symphonie1_Opus21_Mvt3.mid
# 1610
# Building Trajectory for  Symphonie1_Opus21_Mvt4.mid
# 1527
# Building Trajectory for  Symphonie2_Opus36_Mvt1.mid
# 3303
# Building Trajectory for  Symphonie2_Opus36_Mvt2.mid
# 1119
# Building Trajectory for  Symphonie2_Opus36_Mvt3.mid
# 1578
# Building Trajectory for  Symphonie2_Opus36_Mvt4.mid
# 3196
# Building Trajectory for  Symphonie3_Opus55_Mvt1_Heroique.mid
# 3617
# Building Trajectory for  Symphonie3_Opus55_Mvt2_Heroique.mid
# 1276
# Building Trajectory for  Symphonie3_Opus55_Mvt3_Heroique.mid
# 2395
# Building Trajectory for  Symphonie3_Opus55_Mvt4_Heroique.mid
# 2931
# Building Trajectory for  Symphonie4_Opus60_Mvt1.mid
# 2388
# Building Trajectory for  Symphonie4_Opus60_Mvt2.mid
# 1242
# Building Trajectory for  Symphonie4_Opus60_Mvt3.mid
# 1611
# Building Trajectory for  Symphonie4_Opus60_Mvt4.mid
# 2471
# Building Trajectory for  Symphonie5_Opus67_Mvt1.mid
# 1543
# Building Trajectory for  Symphonie5_Opus67_Mvt2.mid
# 955
# Building Trajectory for  Symphonie5_Opus67_Mvt3.mid
# 1342
# Building Trajectory for  Symphonie5_Opus67_Mvt4.mid
# 2575
# Building Trajectory for  Symphonie6_Opus68_Mvt1_Pastorale.mid
# 3177
# Building Trajectory for  Symphonie6_Opus68_Mvt2_Pastorale.mid
# 1850
# Building Trajectory for  Symphonie6_Opus68_Mvt3_Pastorale.mid
# 1392
# Building Trajectory for  Symphonie6_Opus68_Mvt4_Pastorale.mid
# 1247
# Building Trajectory for  Symphonie6_Opus68_Mvt5_Pastorale.mid
# 1367
# Building Trajectory for  Symphonie7_Opus92_Mvt1.mid
# 2406
# Building Trajectory for  Symphonie7_Opus92_Mvt2.mid
# 1203
# Building Trajectory for  Symphonie7_Opus92_Mvt3.mid
# 2713
# Building Trajectory for  Symphonie7_Opus92_Mvt4.mid
# 2490
# [9, 8] dict_items([(9, (13, 16))]) (13, 16) 3 2 1
# --> Cannot build Trajectory for  Symphonie7_Opus92_Mvt4.mid
# Building Trajectory for  Symphonie8_Opus93_Mvt1.mid
# 1767
# Building Trajectory for  Symphonie8_Opus93_Mvt2.mid
# 588
# [10, 9] dict_items([(10, (21, 28))]) (21, 28) 3 2 1
# --> Cannot build Trajectory for  Symphonie8_Opus93_Mvt2.mid
# Building Trajectory for  Symphonie8_Opus93_Mvt3.mid
# 1096
# Building Trajectory for  Symphonie8_Opus93_Mvt4.mid
# 3420
# Building Trajectory for  Symphonie9_Opus125_Mvt1_Choral.mid
# 2600
# Building Trajectory for  Symphonie9_Opus125_Mvt2_Choral.mid
# 5038
# Building Trajectory for  Symphonie9_Opus125_Mvt3_Choral.mid
# 1314
# Building Trajectory for  Symphonie9_Opus125_Mvt4_Choral.mid
# 5099
# Building Trajectory for  C:\Users\melki\AppData\Local\Programs\Python\Python36-32\Lib\site-packages\music21\corpus\beethoven\opus132.mxl
# Building Trajectory for  C:\Users\melki\AppData\Local\Programs\Python\Python36-32\Lib\site-packages\music21\corpus\beethoven\opus133.mxl
# Building Trajectory for  C:\Users\melki\AppData\Local\Programs\Python\Python36-32\Lib\site-packages\music21\corpus\beethoven\opus18no1\movement1.krn
# Building Trajectory for  C:\Users\melki\AppData\Local\Programs\Python\Python36-32\Lib\site-packages\music21\corpus\beethoven\opus18no1\movement1.mxl
# Building Trajectory for  C:\Users\melki\AppData\Local\Programs\Python\Python36-32\Lib\site-packages\music21\corpus\beethoven\opus18no1\movement2.krn
# Building Trajectory for  C:\Users\melki\AppData\Local\Programs\Python\Python36-32\Lib\site-packages\music21\corpus\beethoven\opus18no1\movement2.mxl
# Building Trajectory for  C:\Users\melki\AppData\Local\Programs\Python\Python36-32\Lib\site-packages\music21\corpus\beethoven\opus18no1\movement3.krn
# Building Trajectory for  C:\Users\melki\AppData\Local\Programs\Python\Python36-32\Lib\site-packages\music21\corpus\beethoven\opus18no1\movement3.mxl
# Building Trajectory for  C:\Users\melki\AppData\Local\Programs\Python\Python36-32\Lib\site-packages\music21\corpus\beethoven\opus18no1\movement4.krn
# Building Trajectory for  C:\Users\melki\AppData\Local\Programs\Python\Python36-32\Lib\site-packages\music21\corpus\beethoven\opus18no1\movement4.mxl
# Building Trajectory for  C:\Users\melki\AppData\Local\Programs\Python\Python36-32\Lib\site-packages\music21\corpus\beethoven\opus18no3.mxl
# [5, 1, 8] dict_items([(5, (104, 103)), (1, (103, 103))]) (104, 103) 4 3 2
# --> Cannot build Trajectory for  C:\Users\melki\AppData\Local\Programs\Python\Python36-32\Lib\site-packages\music21\corpus\beethoven\opus18no3.mxl
# Building Trajectory for  C:\Users\melki\AppData\Local\Programs\Python\Python36-32\Lib\site-packages\music21\corpus\beethoven\opus18no4.mxl
# Building Trajectory for  C:\Users\melki\AppData\Local\Programs\Python\Python36-32\Lib\site-packages\music21\corpus\beethoven\opus18no5.mxl
# Building Trajectory for  C:\Users\melki\AppData\Local\Programs\Python\Python36-32\Lib\site-packages\music21\corpus\beethoven\opus59no1\movement1.mxl
# Building Trajectory for  C:\Users\melki\AppData\Local\Programs\Python\Python36-32\Lib\site-packages\music21\corpus\beethoven\opus59no1\movement2.mxl
# Building Trajectory for  C:\Users\melki\AppData\Local\Programs\Python\Python36-32\Lib\site-packages\music21\corpus\beethoven\opus59no1\movement3.mxl
# Building Trajectory for  C:\Users\melki\AppData\Local\Programs\Python\Python36-32\Lib\site-packages\music21\corpus\beethoven\opus59no1\movement4.mxl
# Building Trajectory for  C:\Users\melki\AppData\Local\Programs\Python\Python36-32\Lib\site-packages\music21\corpus\beethoven\opus59no2\movement1.mxl
# Building Trajectory for  C:\Users\melki\AppData\Local\Programs\Python\Python36-32\Lib\site-packages\music21\corpus\beethoven\opus59no2\movement2.mxl
# Building Trajectory for  C:\Users\melki\AppData\Local\Programs\Python\Python36-32\Lib\site-packages\music21\corpus\beethoven\opus59no2\movement3.mxl
# Building Trajectory for  C:\Users\melki\AppData\Local\Programs\Python\Python36-32\Lib\site-packages\music21\corpus\beethoven\opus59no2\movement4.mxl
# Building Trajectory for  C:\Users\melki\AppData\Local\Programs\Python\Python36-32\Lib\site-packages\music21\corpus\beethoven\opus59no3\movement1.mxl
# Building Trajectory for  C:\Users\melki\AppData\Local\Programs\Python\Python36-32\Lib\site-packages\music21\corpus\beethoven\opus59no3\movement2.mxl
# Building Trajectory for  C:\Users\melki\AppData\Local\Programs\Python\Python36-32\Lib\site-packages\music21\corpus\beethoven\opus59no3\movement3.mxl
# Building Trajectory for  C:\Users\melki\AppData\Local\Programs\Python\Python36-32\Lib\site-packages\music21\corpus\beethoven\opus59no3\movement4.mxl
# Building Trajectory for  C:\Users\melki\AppData\Local\Programs\Python\Python36-32\Lib\site-packages\music21\corpus\beethoven\opus74.mxl

# %%
pickleSave(bach, 'bach')
pickleSave(beethoven, 'beethoven')
pickleSave(beethovenCorpus, 'beethovenCorpus')

# %%
chopin = GetWorksByDirectory('Midi_files/Classical/Chopin', 'chopin', 'classical')
chopinCorpus = GetWorksByComposer('chopin', 'chopin', 'classical')
# Out:
# Building Trajectory for  56336a_polonaise_op_53_(nc)smythe.mid
# 2674
# Building Trajectory for  69521a_etude_(aeolian_harp)_op_25_no_1_(nc)smythe.mid
# 1308
# Building Trajectory for  andante_polacca_22_(c)finley.mid
# 5719
# Building Trajectory for  chopin_mazurkas_67_2.mid
# 591
# Building Trajectory for  chopin_polonaise-fantasie_61_(c)lubetsky.mid
# 3987
# Building Trajectory for  chopin_raindrop_prelude.mid
# 413
# Building Trajectory for  chpn-p1.mid
# 246
# Building Trajectory for  chpn-p10.mid
# 185
# [9, 8] dict_items([(9, (2, 1))]) (2, 1) 3 2 1
# --> Cannot build Trajectory for  chpn-p10.mid
# Building Trajectory for  chpn-p11.mid
# 147
# Building Trajectory for  chpn-p12.mid
# 394
# Building Trajectory for  chpn-p13.mid
# 384
# Building Trajectory for  chpn-p14.mid
# 217
# Building Trajectory for  chpn-p15.mid
# 375
# Building Trajectory for  chpn-p16.mid
# 707
# Building Trajectory for  chpn-p17.mid
# 348
# Building Trajectory for  chpn-p18.mid
# 243
# [1, 0] dict_items([(1, (7, -4))]) (7, -4) 3 2 1
# --> Cannot build Trajectory for  chpn-p18.mid
# Building Trajectory for  chpn-p19.mid
# 544
# Building Trajectory for  chpn-p2.mid
# 159
# Building Trajectory for  chpn-p20.mid
# 59
# Building Trajectory for  chpn-p21.mid
# 326
# Building Trajectory for  chpn-p22.mid
# 230
# Building Trajectory for  chpn-p23.mid
# 327
# Building Trajectory for  chpn-p24.mid
# 877
# Building Trajectory for  chpn-p3.mid
# 476
# Building Trajectory for  chpn-p4.mid
# 97
# Building Trajectory for  chpn-p5.mid
# 220
# Building Trajectory for  chpn-p6.mid
# 90
# Building Trajectory for  chpn-p7.mid
# 34
# Building Trajectory for  chpn-p8.mid
# 824
# Building Trajectory for  chpn-p9.mid
# 145
# Building Trajectory for  chpn_op10_e01.mid
# 1231
# Building Trajectory for  chpn_op10_e05.mid
# 880
# Building Trajectory for  chpn_op10_e12.mid
# 1216
# Building Trajectory for  chpn_op23.mid
# 2339
# Building Trajectory for  chpn_op25_e1.mid
# 1104
# Building Trajectory for  chpn_op25_e11.mid
# 2298
# Building Trajectory for  chpn_op25_e12.mid
# 1088
# Building Trajectory for  chpn_op25_e2.mid
# 1012
# Building Trajectory for  chpn_op25_e3.mid
# 596
# Building Trajectory for  chpn_op25_e4.mid
# 719
# Building Trajectory for  chpn_op27_1.mid
# 949
# Building Trajectory for  chpn_op27_2.mid
# 960
# Building Trajectory for  chpn_op7_1.mid
# 581
# Building Trajectory for  chpn_op7_2.mid
# 527
# Building Trajectory for  chp_op18.mid
# 1792
# Building Trajectory for  etude_10_3_oguri.mid
# 1114
# Building Trajectory for  etude_25_1_(c)unknown.mid
# 1513
# Building Trajectory for  etude_25_6_(c)unknown.mid
# 1240
# Building Trajectory for  etude_25_7_(c)unknown.mid
# 1501
# Building Trajectory for  etude_25_9_(c)unknown.mid
# 372
# Building Trajectory for  etude_op_25_1_336_r_(nc)smythe.mid
# 1633
# Building Trajectory for  nocturne_15_1_(c)finley.mid
# 1310
# C:\Users\melki\AppData\Local\Programs\Python\Python36-32\lib\site-packages\pretty_midi\pretty_midi.py:100: RuntimeWarning: Tempo, Key or Time signature change events found on non-zero tracks.  This is not a valid type 0 or type 1 MIDI file.  Tempo, Key or Time Signature may be wrong.
#   RuntimeWarning)
# Building Trajectory for  nocturne_15_1_(c)unknown.mid
# 1008
# Building Trajectory for  nocturne_62_2_(c)unknown.mid
# 984
# Building Trajectory for  nocturne_72_1_(c)unknown.mid
# 748
# Building Trajectory for  nocturne_9_1_(c)unknown.mid
# 1204
# Building Trajectory for  nocturne_9_2_(c)unknown.mid
# 622
# Building Trajectory for  nocturne_9_3_(c)unknown.mid
# 1749
# Building Trajectory for  nocturne_c_minor_(c)inoue.mid
# 538
# Building Trajectory for  nocturne_op_9_1_2979_r_(nc)smythe.mid
# 1615
# Building Trajectory for  C:\Users\melki\AppData\Local\Programs\Python\Python36-32\Lib\site-packages\music21\corpus\chopin\mazurka06-2.krn

# %%
mozart = GetWorksByDirectory('Midi_files/Classical/Mozart', 'mozart', 'classical')
mozartCorpus = GetWorksByComposer('mozart', 'mozart', 'classical')
# Out:
# Building Trajectory for  Ad_fug.mid
# 1814
# [7, 8] dict_items([(7, (103, 105))]) (103, 105) 3 2 1
# --> Cannot build Trajectory for  Ad_fug.mid
# Building Trajectory for  Conc_clarinet-1.mid
# 4176
# Building Trajectory for  Conc_clarinet-2.mid
# 679
# Building Trajectory for  Conc_clarinet-3.mid
# 2994
# Building Trajectory for  mz_333_1.mid
# 4110
# Building Trajectory for  mz_333_2.mid
# 1434
# Building Trajectory for  mz_333_3.mid
# 2193
# Building Trajectory for  mz_570_1.mid
# 2670
# Building Trajectory for  mz_570_2.mid
# 1020
# Building Trajectory for  mz_570_3.mid
# 1234
# Building Trajectory for  piano_sonata_310_1_(c)oguri.mid
# 2321
# Building Trajectory for  piano_sonata_310_2_(c)oguri.mid
# 2418
# Building Trajectory for  piano_sonata_310_3_(c)oguri.mid
# 1430
# Building Trajectory for  piano_sonata_330_1_(c)oguri.mid
# 2038
# [5, 4] dict_items([(5, (4, 3))]) (4, 3) 3 2 1
# --> Cannot build Trajectory for  piano_sonata_330_1_(c)oguri.mid
# Building Trajectory for  piano_sonata_330_2_(c)oguri.mid
# 790
# Building Trajectory for  piano_sonata_330_3_(c)oguri.mid
# 2006
# Building Trajectory for  piano_sonata_331_1_(c)oguri.mid
# 2601
# Building Trajectory for  piano_sonata_331_2_(c)oguri.mid
# 1428
# [4, 8] dict_items([(4, (103, 104))]) (103, 104) 3 2 1
# --> Cannot build Trajectory for  piano_sonata_331_2_(c)oguri.mid
# Building Trajectory for  piano_sonata_331_3_(c)oguri.mid
# 1506
# [9, 8] dict_items([(9, (1, 2))]) (1, 2) 3 2 1
# --> Cannot build Trajectory for  piano_sonata_331_3_(c)oguri.mid
# Building Trajectory for  piano_sonata_332_1_(c)oguri.mid
# 1751
# Building Trajectory for  piano_sonata_332_2_(c)oguri.mid
# 1359
# Building Trajectory for  piano_sonata_332_3_(c)oguri.mid
# 2455
# Building Trajectory for  piano_sonata_333_1_(c)oguri.mid
# 2638
# [3, 2] dict_items([(3, (2, -1))]) (2, -1) 3 2 1
# --> Cannot build Trajectory for  piano_sonata_333_1_(c)oguri.mid
# Building Trajectory for  piano_sonata_333_2_(c)oguri.mid
# 1460
# Building Trajectory for  piano_sonata_333_3_(c)oguri.mid
# 2822
# Building Trajectory for  piano_sonata_457_1_(c)oguri.mid
# 1806
# Building Trajectory for  piano_sonata_457_2_(c)oguri.mid
# 1986
# Building Trajectory for  piano_sonata_457_3_(c)oguri.mid
# 1852
# Building Trajectory for  piano_sonata_545_1_(c)oguri.mid
# 1254
# [5, 0, 11] dict_items([(5, (1, 1)), (0, (0, 0))]) (1, 1) 4 3 2
# --> Cannot build Trajectory for  piano_sonata_545_1_(c)oguri.mid
# Building Trajectory for  piano_sonata_545_2_(c)oguri.mid
# 1334
# Building Trajectory for  piano_sonata_545_3_(c)oguri.mid
# 662
# Building Trajectory for  piano_sonata_570_1_(c)oguri.mid
# 1873
# [3, 2] dict_items([(3, (5, 6))]) (5, 6) 3 2 1
# --> Cannot build Trajectory for  piano_sonata_570_1_(c)oguri.mid
# Building Trajectory for  piano_sonata_570_2_(c)oguri.mid
# 1271
# Building Trajectory for  Symph29-1.mid
# 2353
# Building Trajectory for  Symph29-2.mid
# 1077
# Building Trajectory for  Symph29-3.mid
# 742
# Building Trajectory for  Symph29-4.mid
# 1523
# Building Trajectory for  C:\Users\melki\AppData\Local\Programs\Python\Python36-32\Lib\site-packages\music21\corpus\mozart\k155\movement1.mxl
# Building Trajectory for  C:\Users\melki\AppData\Local\Programs\Python\Python36-32\Lib\site-packages\music21\corpus\mozart\k155\movement2.mxl
# Building Trajectory for  C:\Users\melki\AppData\Local\Programs\Python\Python36-32\Lib\site-packages\music21\corpus\mozart\k155\movement3.mxl
# Building Trajectory for  C:\Users\melki\AppData\Local\Programs\Python\Python36-32\Lib\site-packages\music21\corpus\mozart\k156\movement1.mxl
# Building Trajectory for  C:\Users\melki\AppData\Local\Programs\Python\Python36-32\Lib\site-packages\music21\corpus\mozart\k156\movement2.mxl
# Building Trajectory for  C:\Users\melki\AppData\Local\Programs\Python\Python36-32\Lib\site-packages\music21\corpus\mozart\k156\movement3.mxl
# Building Trajectory for  C:\Users\melki\AppData\Local\Programs\Python\Python36-32\Lib\site-packages\music21\corpus\mozart\k156\movement4.mxl
# Building Trajectory for  C:\Users\melki\AppData\Local\Programs\Python\Python36-32\Lib\site-packages\music21\corpus\mozart\k458\movement1.mxl
# Building Trajectory for  C:\Users\melki\AppData\Local\Programs\Python\Python36-32\Lib\site-packages\music21\corpus\mozart\k458\movement2.mxl
# Building Trajectory for  C:\Users\melki\AppData\Local\Programs\Python\Python36-32\Lib\site-packages\music21\corpus\mozart\k458\movement3.mxl
# Building Trajectory for  C:\Users\melki\AppData\Local\Programs\Python\Python36-32\Lib\site-packages\music21\corpus\mozart\k458\movement4.mxl
# Building Trajectory for  C:\Users\melki\AppData\Local\Programs\Python\Python36-32\Lib\site-packages\music21\corpus\mozart\k545\movement1_exposition.mxl
# Building Trajectory for  C:\Users\melki\AppData\Local\Programs\Python\Python36-32\Lib\site-packages\music21\corpus\mozart\k80\movement1.mxl
# Building Trajectory for  C:\Users\melki\AppData\Local\Programs\Python\Python36-32\Lib\site-packages\music21\corpus\mozart\k80\movement2.mxl
# Building Trajectory for  C:\Users\melki\AppData\Local\Programs\Python\Python36-32\Lib\site-packages\music21\corpus\mozart\k80\movement3.mxl
# Building Trajectory for  C:\Users\melki\AppData\Local\Programs\Python\Python36-32\Lib\site-packages\music21\corpus\mozart\k80\movement4.mxl

# %%
schumann = GetWorksByDirectory('Midi_files/Classical/Schumann', 'schumann', 'classical')
schumannCorpus = GetWorksByComposer('schumann', 'schumann', 'classical')
# Out:
# Building Trajectory for  By-The-Fireside-Opus-15-(8th-Movement).mid
# 363
# Building Trajectory for  Catch-Me!-Opus-15-(3rd-Movement).mid
# 297
# Building Trajectory for  Child-Falling-Asleep-Opus-15-(12th-Movement).mid
# 367
# Building Trajectory for  Curious-Story-Opus-15-(2nd-Movement).mid
# 370
# Building Trajectory for  Fantasy-Pieces-in-A-Flat-Opus-111-Nr-2.mid
# 1179
# Building Trajectory for  Fantasy-Pieces-in-C-Minor-Opus-111-Nr-1.mid
# 1445
# Building Trajectory for  Fantasy-Pieces-in-C-Minor-Opus-111-Nr-3.mid
# 918
# Building Trajectory for  Fantasy-Pieces-Opus-12-Nr-6.mid
# 756
# Building Trajectory for  Foreign-Land-And-People-Opus-15-(1st-Movement).mid
# 431
# Building Trajectory for  Friendly-Landscape-From-Waldscenen.mid
# 469
# Building Trajectory for  Frightening-Opus-15-(11th-Movement).mid
# 562
# Building Trajectory for  Fruhlingsnacht.mid
# 1041
# Building Trajectory for  Important-Event-Opus-15-(6st-Movement).mid
# 216
# Building Trajectory for  In-The-Evening-Opus-12-Nr-1.mid
# 1115
# [7, 1] dict_items([(7, (0, 3))]) (0, 3) 3 2 1
# --> Cannot build Trajectory for  In-The-Evening-Opus-12-Nr-1.mid
# Building Trajectory for  In-The-Night-Opus-12-Nr-5.mid
# 2491
# Building Trajectory for  Knight-Of-The-Rocking-Horse-Opus-15-(8th-Movement).mid
# 314
# Building Trajectory for  Novelette-Opus-21-Nr-7.mid
# 1373
# Building Trajectory for  Perfect-Happiness-Opus-15-(5th-Movement).mid
# 297
# Building Trajectory for  Piano-Piece-Nr-01.mid
# 189
# Building Trajectory for  Piano-Piece-Nr-02.mid
# 104
# Building Trajectory for  Piano-Piece-Nr-03.mid
# 177
# Building Trajectory for  Piano-Piece-Nr-04.mid
# 62
# Building Trajectory for  Piano-Piece-Nr-05.mid
# 181
# Building Trajectory for  Piano-Piece-Nr-06.mid
# 138
# Building Trajectory for  Piano-Piece-Nr-07.mid
# 232
# Building Trajectory for  Piano-Piece-Nr-08.mid
# 189
# Building Trajectory for  Piano-Piece-Nr-09.mid
# 128
# Building Trajectory for  Piano-Piece-Nr-10.mid
# 209
# Building Trajectory for  Pleading-Child-Opus-15-(4th-Movement).mid
# 238
# Building Trajectory for  Restless-Dreams-Opus-12-Nr-7.mid
# 1403
# [11, 5] dict_items([(11, (5, 10))]) (5, 10) 3 2 1
# --> Cannot build Trajectory for  Restless-Dreams-Opus-12-Nr-7.mid
# Building Trajectory for  Reverie-Opus-15-(17th-Movement).mid
# 402
# Building Trajectory for  Romanze-in-F-Sharp-Opus-28-Nr-2.mid
# 887
# Building Trajectory for  schum_abegg.mid
# 2663
# Building Trajectory for  scn15_1.mid
# 283
# Building Trajectory for  scn15_10.mid
# 194
# Building Trajectory for  scn15_11.mid
# 297
# Building Trajectory for  scn15_12.mid
# 139
# Building Trajectory for  scn15_13.mid
# 108
# Building Trajectory for  scn15_2.mid
# 206
# Building Trajectory for  scn15_3.mid
# 247
# Building Trajectory for  scn15_4.mid
# 123
# Building Trajectory for  scn15_5.mid
# 314
# Building Trajectory for  scn15_6.mid
# 133
# Building Trajectory for  scn15_7.mid
# 177
# Building Trajectory for  scn15_8.mid
# 166
# Building Trajectory for  scn15_9.mid
# 138
# Building Trajectory for  scn16_1.mid
# 1566
# Building Trajectory for  scn16_2.mid
# 1491
# Building Trajectory for  scn16_3.mid
# 1304
# Building Trajectory for  scn16_4.mid
# 307
# Building Trajectory for  scn16_5.mid
# 945
# Building Trajectory for  scn16_6.mid
# 305
# [10, 9] dict_items([(10, (3, 1))]) (3, 1) 3 2 1
# --> Cannot build Trajectory for  scn16_6.mid
# Building Trajectory for  scn16_7.mid
# 913
# Building Trajectory for  scn16_8.mid
# 1278
# Building Trajectory for  scn68_10.mid
# 121
# Building Trajectory for  scn68_12.mid
# 543
# Building Trajectory for  Soaring-Opus-12-Nr-2.mid
# 1576
# [1, 0] dict_items([(1, (2, 3))]) (2, 3) 3 2 1
# --> Cannot build Trajectory for  Soaring-Opus-12-Nr-2.mid
# Building Trajectory for  The-Arabeske-Opus-18.mid
# 2277
# Building Trajectory for  The-Happy-Farmer-Return-From-Work-Opus-68.mid
# 243
# Building Trajectory for  The-Poet-Speaks-Opus-15-(13th-Movement).mid
# 234
# Building Trajectory for  The-Songs-End-Opus-12-Nr-8.mid
# 937
# Building Trajectory for  Traumerei-Opus-15-Nr-17.mid
# 232
# Building Trajectory for  Why-Opus-12-Nr-3.mid
# 391
# Building Trajectory for  C:\Users\melki\AppData\Local\Programs\Python\Python36-32\Lib\site-packages\music21\corpus\schumann\dichterliebe_no2.xml
# Building Trajectory for  C:\Users\melki\AppData\Local\Programs\Python\Python36-32\Lib\site-packages\music21\corpus\schumann\opus41no1\movement1.mxl
# Building Trajectory for  C:\Users\melki\AppData\Local\Programs\Python\Python36-32\Lib\site-packages\music21\corpus\schumann\opus41no1\movement2.mxl
# Building Trajectory for  C:\Users\melki\AppData\Local\Programs\Python\Python36-32\Lib\site-packages\music21\corpus\schumann\opus41no1\movement3.mxl
# Building Trajectory for  C:\Users\melki\AppData\Local\Programs\Python\Python36-32\Lib\site-packages\music21\corpus\schumann\opus41no1\movement4.xml
# Building Trajectory for  C:\Users\melki\AppData\Local\Programs\Python\Python36-32\Lib\site-packages\music21\corpus\schumann\opus41no1\movement5.mxl
# Building Trajectory for  C:\Users\melki\AppData\Local\Programs\Python\Python36-32\Lib\site-packages\music21\corpus\schumann\opus48no2.mxl

# %%
palestrina = GetWorksByComposer('palestrina', 'palestrina', 'renaissance')
monteverdi = GetWorksByComposer('monteverdi', 'monteverdi', 'renaissance')
# Out:
# Building Trajectory for  C:\Users\melki\AppData\Local\Programs\Python\Python36-32\Lib\site-packages\music21\corpus\palestrina\Agnus.krn
# Building Trajectory for  C:\Users\melki\AppData\Local\Programs\Python\Python36-32\Lib\site-packages\music21\corpus\palestrina\Agnus_00.krn
# Building Trajectory for  C:\Users\melki\AppData\Local\Programs\Python\Python36-32\Lib\site-packages\music21\corpus\palestrina\Agnus_01.krn
# Building Trajectory for  C:\Users\melki\AppData\Local\Programs\Python\Python36-32\Lib\site-packages\music21\corpus\palestrina\Agnus_02.krn
# Building Trajectory for  C:\Users\melki\AppData\Local\Programs\Python\Python36-32\Lib\site-packages\music21\corpus\palestrina\Agnus_03.krn
# Building Trajectory for  C:\Users\melki\AppData\Local\Programs\Python\Python36-32\Lib\site-packages\music21\corpus\palestrina\Agnus_04.krn
# Building Trajectory for  C:\Users\melki\AppData\Local\Programs\Python\Python36-32\Lib\site-packages\music21\corpus\palestrina\Agnus_05.krn
# Building Trajectory for  C:\Users\melki\AppData\Local\Programs\Python\Python36-32\Lib\site-packages\music21\corpus\palestrina\Agnus_06.krn
# Building Trajectory for  C:\Users\melki\AppData\Local\Programs\Python\Python36-32\Lib\site-packages\music21\corpus\palestrina\Agnus_07.krn
# Building Trajectory for  C:\Users\melki\AppData\Local\Programs\Python\Python36-32\Lib\site-packages\music21\corpus\palestrina\Agnus_08.krn
# Building Trajectory for  C:\Users\melki\AppData\Local\Programs\Python\Python36-32\Lib\site-packages\music21\corpus\palestrina\Agnus_09.krn
# Building Trajectory for  C:\Users\melki\AppData\Local\Programs\Python\Python36-32\Lib\site-packages\music21\corpus\palestrina\Agnus_10.krn
# Building Trajectory for  C:\Users\melki\AppData\Local\Programs\Python\Python36-32\Lib\site-packages\music21\corpus\palestrina\Agnus_11.krn
# Building Trajectory for  C:\Users\melki\AppData\Local\Programs\Python\Python36-32\Lib\site-packages\music21\corpus\palestrina\Agnus_12.krn
# Building Trajectory for  C:\Users\melki\AppData\Local\Programs\Python\Python36-32\Lib\site-packages\music21\corpus\palestrina\Agnus_13.krn
# Building Trajectory for  C:\Users\melki\AppData\Local\Programs\Python\Python36-32\Lib\site-packages\music21\corpus\palestrina\Agnus_14.krn
# Building Trajectory for  C:\Users\melki\AppData\Local\Programs\Python\Python36-32\Lib\site-packages\music21\corpus\palestrina\Agnus_15.krn
# Building Trajectory for  C:\Users\melki\AppData\Local\Programs\Python\Python36-32\Lib\site-packages\music21\corpus\palestrina\Agnus_16.krn
# Building Trajectory for  C:\Users\melki\AppData\Local\Programs\Python\Python36-32\Lib\site-packages\music21\corpus\palestrina\Agnus_17.krn
# Building Trajectory for  C:\Users\melki\AppData\Local\Programs\Python\Python36-32\Lib\site-packages\music21\corpus\palestrina\Agnus_I.krn
# Building Trajectory for  C:\Users\melki\AppData\Local\Programs\Python\Python36-32\Lib\site-packages\music21\corpus\palestrina\Agnus_I_00.krn
# Building Trajectory for  C:\Users\melki\AppData\Local\Programs\Python\Python36-32\Lib\site-packages\music21\corpus\palestrina\Agnus_I_01.krn
# Building Trajectory for  C:\Users\melki\AppData\Local\Programs\Python\Python36-32\Lib\site-packages\music21\corpus\palestrina\Agnus_I_02.krn
# Building Trajectory for  C:\Users\melki\AppData\Local\Programs\Python\Python36-32\Lib\site-packages\music21\corpus\palestrina\Agnus_I_03.krn
# Building Trajectory for  C:\Users\melki\AppData\Local\Programs\Python\Python36-32\Lib\site-packages\music21\corpus\palestrina\Agnus_I_04.krn
# Building Trajectory for  C:\Users\melki\AppData\Local\Programs\Python\Python36-32\Lib\site-packages\music21\corpus\palestrina\Agnus_I_05.krn
# Building Trajectory for  C:\Users\melki\AppData\Local\Programs\Python\Python36-32\Lib\site-packages\music21\corpus\palestrina\Agnus_I_06.krn
# Building Trajectory for  C:\Users\melki\AppData\Local\Programs\Python\Python36-32\Lib\site-packages\music21\corpus\palestrina\Agnus_I_07.krn
# Building Trajectory for  C:\Users\melki\AppData\Local\Programs\Python\Python36-32\Lib\site-packages\music21\corpus\palestrina\Agnus_I_08.krn
# Building Trajectory for  C:\Users\melki\AppData\Local\Programs\Python\Python36-32\Lib\site-packages\music21\corpus\palestrina\Agnus_I_09.krn
# Building Trajectory for  C:\Users\melki\AppData\Local\Programs\Python\Python36-32\Lib\site-packages\music21\corpus\palestrina\Agnus_I_10.krn
# Building Trajectory for  C:\Users\melki\AppData\Local\Programs\Python\Python36-32\Lib\site-packages\music21\corpus\palestrina\Agnus_I_11.krn
# Building Trajectory for  C:\Users\melki\AppData\Local\Programs\Python\Python36-32\Lib\site-packages\music21\corpus\palestrina\Agnus_I_12.krn
# Building Trajectory for  C:\Users\melki\AppData\Local\Programs\Python\Python36-32\Lib\site-packages\music21\corpus\palestrina\Agnus_I_13.krn
# Building Trajectory for  C:\Users\melki\AppData\Local\Programs\Python\Python36-32\Lib\site-packages\music21\corpus\palestrina\Agnus_I_14.krn
# Building Trajectory for  C:\Users\melki\AppData\Local\Programs\Python\Python36-32\Lib\site-packages\music21\corpus\palestrina\Agnus_I_15.krn
# Building Trajectory for  C:\Users\melki\AppData\Local\Programs\Python\Python36-32\Lib\site-packages\music21\corpus\palestrina\Agnus_I_16.krn
# Building Trajectory for  C:\Users\melki\AppData\Local\Programs\Python\Python36-32\Lib\site-packages\music21\corpus\palestrina\Agnus_I_17.krn
# Building Trajectory for  C:\Users\melki\AppData\Local\Programs\Python\Python36-32\Lib\site-packages\music21\corpus\palestrina\Agnus_I_18.krn
# Building Trajectory for  C:\Users\melki\AppData\Local\Programs\Python\Python36-32\Lib\site-packages\music21\corpus\palestrina\Agnus_I_19.krn
# Building Trajectory for  C:\Users\melki\AppData\Local\Programs\Python\Python36-32\Lib\site-packages\music21\corpus\palestrina\Agnus_I_20.krn
# Building Trajectory for  C:\Users\melki\AppData\Local\Programs\Python\Python36-32\Lib\site-packages\music21\corpus\palestrina\Agnus_I_21.krn
# Building Trajectory for  C:\Users\melki\AppData\Local\Programs\Python\Python36-32\Lib\site-packages\music21\corpus\palestrina\Agnus_I_22.krn
# Building Trajectory for  C:\Users\melki\AppData\Local\Programs\Python\Python36-32\Lib\site-packages\music21\corpus\palestrina\Agnus_I_23.krn
# Building Trajectory for  C:\Users\melki\AppData\Local\Programs\Python\Python36-32\Lib\site-packages\music21\corpus\palestrina\Agnus_I_24.krn
# Building Trajectory for  C:\Users\melki\AppData\Local\Programs\Python\Python36-32\Lib\site-packages\music21\corpus\palestrina\Agnus_I_25.krn
# Building Trajectory for  C:\Users\melki\AppData\Local\Programs\Python\Python36-32\Lib\site-packages\music21\corpus\palestrina\Agnus_I_26.krn
# Building Trajectory for  C:\Users\melki\AppData\Local\Programs\Python\Python36-32\Lib\site-packages\music21\corpus\palestrina\Agnus_I_27.krn
# Building Trajectory for  C:\Users\melki\AppData\Local\Programs\Python\Python36-32\Lib\site-packages\music21\corpus\palestrina\Agnus_I_28.krn
# Building Trajectory for  C:\Users\melki\AppData\Local\Programs\Python\Python36-32\Lib\site-packages\music21\corpus\palestrina\Agnus_I_29.krn
# Building Trajectory for  C:\Users\melki\AppData\Local\Programs\Python\Python36-32\Lib\site-packages\music21\corpus\palestrina\Agnus_I_30.krn
# Building Trajectory for  C:\Users\melki\AppData\Local\Programs\Python\Python36-32\Lib\site-packages\music21\corpus\palestrina\Agnus_I_31.krn
# Building Trajectory for  C:\Users\melki\AppData\Local\Programs\Python\Python36-32\Lib\site-packages\music21\corpus\palestrina\Agnus_I_32.krn
# Building Trajectory for  C:\Users\melki\AppData\Local\Programs\Python\Python36-32\Lib\site-packages\music21\corpus\palestrina\Agnus_I_33.krn
# Building Trajectory for  C:\Users\melki\AppData\Local\Programs\Python\Python36-32\Lib\site-packages\music21\corpus\palestrina\Agnus_I_34.krn
# Building Trajectory for  C:\Users\melki\AppData\Local\Programs\Python\Python36-32\Lib\site-packages\music21\corpus\palestrina\Agnus_I_35.krn
# Building Trajectory for  C:\Users\melki\AppData\Local\Programs\Python\Python36-32\Lib\site-packages\music21\corpus\palestrina\Agnus_I_36.krn
# Building Trajectory for  C:\Users\melki\AppData\Local\Programs\Python\Python36-32\Lib\site-packages\music21\corpus\palestrina\Agnus_I_37.krn
# Building Trajectory for  C:\Users\melki\AppData\Local\Programs\Python\Python36-32\Lib\site-packages\music21\corpus\palestrina\Agnus_I_38.krn
# Building Trajectory for  C:\Users\melki\AppData\Local\Programs\Python\Python36-32\Lib\site-packages\music21\corpus\palestrina\Agnus_I_39.krn
# Building Trajectory for  C:\Users\melki\AppData\Local\Programs\Python\Python36-32\Lib\site-packages\music21\corpus\monteverdi\madrigal.3.1.mxl
# Building Trajectory for  C:\Users\melki\AppData\Local\Programs\Python\Python36-32\Lib\site-packages\music21\corpus\monteverdi\madrigal.3.1.rntxt
# Building Trajectory for  C:\Users\melki\AppData\Local\Programs\Python\Python36-32\Lib\site-packages\music21\corpus\monteverdi\madrigal.3.10.mxl
# Building Trajectory for  C:\Users\melki\AppData\Local\Programs\Python\Python36-32\Lib\site-packages\music21\corpus\monteverdi\madrigal.3.10.rntxt
# Building Trajectory for  C:\Users\melki\AppData\Local\Programs\Python\Python36-32\Lib\site-packages\music21\corpus\monteverdi\madrigal.3.11.mxl
# Building Trajectory for  C:\Users\melki\AppData\Local\Programs\Python\Python36-32\Lib\site-packages\music21\corpus\monteverdi\madrigal.3.11.rntxt
# Building Trajectory for  C:\Users\melki\AppData\Local\Programs\Python\Python36-32\Lib\site-packages\music21\corpus\monteverdi\madrigal.3.12.mxl
# Building Trajectory for  C:\Users\melki\AppData\Local\Programs\Python\Python36-32\Lib\site-packages\music21\corpus\monteverdi\madrigal.3.12.rntxt
# Building Trajectory for  C:\Users\melki\AppData\Local\Programs\Python\Python36-32\Lib\site-packages\music21\corpus\monteverdi\madrigal.3.13.mxl
# Building Trajectory for  C:\Users\melki\AppData\Local\Programs\Python\Python36-32\Lib\site-packages\music21\corpus\monteverdi\madrigal.3.13.rntxt
# Building Trajectory for  C:\Users\melki\AppData\Local\Programs\Python\Python36-32\Lib\site-packages\music21\corpus\monteverdi\madrigal.3.14.mxl
# Building Trajectory for  C:\Users\melki\AppData\Local\Programs\Python\Python36-32\Lib\site-packages\music21\corpus\monteverdi\madrigal.3.14.rntxt
# Building Trajectory for  C:\Users\melki\AppData\Local\Programs\Python\Python36-32\Lib\site-packages\music21\corpus\monteverdi\madrigal.3.15.mxl
# Building Trajectory for  C:\Users\melki\AppData\Local\Programs\Python\Python36-32\Lib\site-packages\music21\corpus\monteverdi\madrigal.3.15.rntxt
# Building Trajectory for  C:\Users\melki\AppData\Local\Programs\Python\Python36-32\Lib\site-packages\music21\corpus\monteverdi\madrigal.3.16.mxl
# Building Trajectory for  C:\Users\melki\AppData\Local\Programs\Python\Python36-32\Lib\site-packages\music21\corpus\monteverdi\madrigal.3.16.rntxt
# Building Trajectory for  C:\Users\melki\AppData\Local\Programs\Python\Python36-32\Lib\site-packages\music21\corpus\monteverdi\madrigal.3.17.mxl
# Building Trajectory for  C:\Users\melki\AppData\Local\Programs\Python\Python36-32\Lib\site-packages\music21\corpus\monteverdi\madrigal.3.17.rntxt
# Building Trajectory for  C:\Users\melki\AppData\Local\Programs\Python\Python36-32\Lib\site-packages\music21\corpus\monteverdi\madrigal.3.18.mxl
# Building Trajectory for  C:\Users\melki\AppData\Local\Programs\Python\Python36-32\Lib\site-packages\music21\corpus\monteverdi\madrigal.3.18.rntxt
# Building Trajectory for  C:\Users\melki\AppData\Local\Programs\Python\Python36-32\Lib\site-packages\music21\corpus\monteverdi\madrigal.3.19.mxl
# Building Trajectory for  C:\Users\melki\AppData\Local\Programs\Python\Python36-32\Lib\site-packages\music21\corpus\monteverdi\madrigal.3.19.rntxt
# Building Trajectory for  C:\Users\melki\AppData\Local\Programs\Python\Python36-32\Lib\site-packages\music21\corpus\monteverdi\madrigal.3.1_old.mxl
# Building Trajectory for  C:\Users\melki\AppData\Local\Programs\Python\Python36-32\Lib\site-packages\music21\corpus\monteverdi\madrigal.3.2.mxl
# Building Trajectory for  C:\Users\melki\AppData\Local\Programs\Python\Python36-32\Lib\site-packages\music21\corpus\monteverdi\madrigal.3.2.rntxt
# Building Trajectory for  C:\Users\melki\AppData\Local\Programs\Python\Python36-32\Lib\site-packages\music21\corpus\monteverdi\madrigal.3.20.mxl
# Building Trajectory for  C:\Users\melki\AppData\Local\Programs\Python\Python36-32\Lib\site-packages\music21\corpus\monteverdi\madrigal.3.20.rntxt
# Building Trajectory for  C:\Users\melki\AppData\Local\Programs\Python\Python36-32\Lib\site-packages\music21\corpus\monteverdi\madrigal.3.3.mxl
# Building Trajectory for  C:\Users\melki\AppData\Local\Programs\Python\Python36-32\Lib\site-packages\music21\corpus\monteverdi\madrigal.3.3.rntxt
# Building Trajectory for  C:\Users\melki\AppData\Local\Programs\Python\Python36-32\Lib\site-packages\music21\corpus\monteverdi\madrigal.3.4.mxl
# Building Trajectory for  C:\Users\melki\AppData\Local\Programs\Python\Python36-32\Lib\site-packages\music21\corpus\monteverdi\madrigal.3.4.rntxt
# Building Trajectory for  C:\Users\melki\AppData\Local\Programs\Python\Python36-32\Lib\site-packages\music21\corpus\monteverdi\madrigal.3.5.mxl
# Building Trajectory for  C:\Users\melki\AppData\Local\Programs\Python\Python36-32\Lib\site-packages\music21\corpus\monteverdi\madrigal.3.5.rntxt
# Building Trajectory for  C:\Users\melki\AppData\Local\Programs\Python\Python36-32\Lib\site-packages\music21\corpus\monteverdi\madrigal.3.6.mxl
# Building Trajectory for  C:\Users\melki\AppData\Local\Programs\Python\Python36-32\Lib\site-packages\music21\corpus\monteverdi\madrigal.3.6.rntxt
# Building Trajectory for  C:\Users\melki\AppData\Local\Programs\Python\Python36-32\Lib\site-packages\music21\corpus\monteverdi\madrigal.3.7.mxl
# Building Trajectory for  C:\Users\melki\AppData\Local\Programs\Python\Python36-32\Lib\site-packages\music21\corpus\monteverdi\madrigal.3.7.rntxt
# Building Trajectory for  C:\Users\melki\AppData\Local\Programs\Python\Python36-32\Lib\site-packages\music21\corpus\monteverdi\madrigal.3.8.mxl
# Building Trajectory for  C:\Users\melki\AppData\Local\Programs\Python\Python36-32\Lib\site-packages\music21\corpus\monteverdi\madrigal.3.8.rntxt
# Building Trajectory for  C:\Users\melki\AppData\Local\Programs\Python\Python36-32\Lib\site-packages\music21\corpus\monteverdi\madrigal.3.9.mxl
# Building Trajectory for  C:\Users\melki\AppData\Local\Programs\Python\Python36-32\Lib\site-packages\music21\corpus\monteverdi\madrigal.3.9.rntxt
# Building Trajectory for  C:\Users\melki\AppData\Local\Programs\Python\Python36-32\Lib\site-packages\music21\corpus\monteverdi\madrigal.4.1.mxl
# Building Trajectory for  C:\Users\melki\AppData\Local\Programs\Python\Python36-32\Lib\site-packages\music21\corpus\monteverdi\madrigal.4.1.rntxt
# Building Trajectory for  C:\Users\melki\AppData\Local\Programs\Python\Python36-32\Lib\site-packages\music21\corpus\monteverdi\madrigal.4.10.mxl
# Building Trajectory for  C:\Users\melki\AppData\Local\Programs\Python\Python36-32\Lib\site-packages\music21\corpus\monteverdi\madrigal.4.10.rntxt
# Building Trajectory for  C:\Users\melki\AppData\Local\Programs\Python\Python36-32\Lib\site-packages\music21\corpus\monteverdi\madrigal.4.11.mxl
# Building Trajectory for  C:\Users\melki\AppData\Local\Programs\Python\Python36-32\Lib\site-packages\music21\corpus\monteverdi\madrigal.4.11.rntxt
# Building Trajectory for  C:\Users\melki\AppData\Local\Programs\Python\Python36-32\Lib\site-packages\music21\corpus\monteverdi\madrigal.4.12.mxl
# Building Trajectory for  C:\Users\melki\AppData\Local\Programs\Python\Python36-32\Lib\site-packages\music21\corpus\monteverdi\madrigal.4.12.rntxt
# Building Trajectory for  C:\Users\melki\AppData\Local\Programs\Python\Python36-32\Lib\site-packages\music21\corpus\monteverdi\madrigal.4.13.mxl
# Building Trajectory for  C:\Users\melki\AppData\Local\Programs\Python\Python36-32\Lib\site-packages\music21\corpus\monteverdi\madrigal.4.13.rntxt
# Building Trajectory for  C:\Users\melki\AppData\Local\Programs\Python\Python36-32\Lib\site-packages\music21\corpus\monteverdi\madrigal.4.14.mxl
# Building Trajectory for  C:\Users\melki\AppData\Local\Programs\Python\Python36-32\Lib\site-packages\music21\corpus\monteverdi\madrigal.4.14.rntxt
# Building Trajectory for  C:\Users\melki\AppData\Local\Programs\Python\Python36-32\Lib\site-packages\music21\corpus\monteverdi\madrigal.4.15.mxl
# Building Trajectory for  C:\Users\melki\AppData\Local\Programs\Python\Python36-32\Lib\site-packages\music21\corpus\monteverdi\madrigal.4.15.rntxt
# Building Trajectory for  C:\Users\melki\AppData\Local\Programs\Python\Python36-32\Lib\site-packages\music21\corpus\monteverdi\madrigal.4.16.mxl
# Building Trajectory for  C:\Users\melki\AppData\Local\Programs\Python\Python36-32\Lib\site-packages\music21\corpus\monteverdi\madrigal.4.16.rntxt
# Building Trajectory for  C:\Users\melki\AppData\Local\Programs\Python\Python36-32\Lib\site-packages\music21\corpus\monteverdi\madrigal.4.17.mxl
# Building Trajectory for  C:\Users\melki\AppData\Local\Programs\Python\Python36-32\Lib\site-packages\music21\corpus\monteverdi\madrigal.4.17.rntxt
# Building Trajectory for  C:\Users\melki\AppData\Local\Programs\Python\Python36-32\Lib\site-packages\music21\corpus\monteverdi\madrigal.4.18.mxl

# %%
jazz = GetWorksByDirectory('Midi_files/Standard_Jazz/Random', 'Unknown', 'jazz')
# Out:
# Building Trajectory for  A-Getting-Sentimental-Over-You-1.mid
# 516
# Building Trajectory for  A-Taste-Of-Honey.mid
# 863
# Building Trajectory for  After-You-Gone.mid
# 1547
# Building Trajectory for  All-Of-Me-2.mid
# 2630
# Building Trajectory for  All-The-Things-You-Are.mid
# 2922
# [5, 1, 3, 0, 8, 10] dict_items([(5, (104, 103)), (1, (103, 103)), (3, (105, 105)), (0, (105, 104)), (10, (103, 102))]) (104, 103) 7 6 5
# --> Cannot build Trajectory for  All-The-Things-You-Are.mid
# Building Trajectory for  All-The-Way.mid
# 1383
# Building Trajectory for  Alone-Together.mid
# 874
# Building Trajectory for  Antropology.mid
# 1680
# [3, 2, 8] dict_items([(3, (3, 3)), (8, (4, 4))]) (3, 3) 4 3 2
# --> Cannot build Trajectory for  Antropology.mid
# Building Trajectory for  Anything-Goes.mid
# 1172
# Building Trajectory for  As-Time-Goes-By.mid
# 1091
# Building Trajectory for  Autumn-Leaves.mid
# 1647
# Building Trajectory for  Basin-Street-Blues-1.mid
# 969
# Building Trajectory for  Basin-Street-Blues-2.mid
# 1285
# Building Trajectory for  Bewitched-1.mid
# 970
# Building Trajectory for  Big-Band-Medley-(Medley).mid
# 1334
# Building Trajectory for  Billie's-Bounce-1.mid
# 1831
# [5, 4, 10] dict_items([(5, (2, -1)), (10, (3, 0))]) (2, -1) 4 3 2
# --> Cannot build Trajectory for  Billie's-Bounce-1.mid
# Building Trajectory for  Billie's-Bounce-2.mid
# 1829
# [5, 4, 10] dict_items([(5, (2, -1)), (10, (3, 0))]) (2, -1) 4 3 2
# --> Cannot build Trajectory for  Billie's-Bounce-2.mid
# Building Trajectory for  Black-Orpheus.mid
# 1799
# Building Trajectory for  Brass-Band-Medley-(Medley).mid
# 1133
# Building Trajectory for  Caravan.mid
# 1223
# Building Trajectory for  Come-Fly-With-Me.mid
# 1085
# Building Trajectory for  Count-On-The-Blues (1).mid
# 929
# Building Trajectory for  Count-On-The-Blues.mid
# 929
# Building Trajectory for  Feel-Like-Making-Love.mid
# 1611
# Building Trajectory for  Fools-Rush-In.mid
# 317
# Building Trajectory for  Georgia-On-My-Mind-1.mid
# 667
# Building Trajectory for  Georgia-On-My-Mind-2.mid
# 604
# Building Trajectory for  Greensleeves.mid
# 543
# Building Trajectory for  Happy-Luxembourg.mid
# 1370
# Building Trajectory for  Harlem-Nocturne-1.mid
# 722
# Building Trajectory for  I'll-Remember-April.mid
# 600
# Building Trajectory for  I've-Got-You-Under-My-Skin.mid
# 1580
# [1, 0, 6] dict_items([(1, (3, 2)), (6, (4, 3))]) (3, 2) 4 3 2
# --> Cannot build Trajectory for  I've-Got-You-Under-My-Skin.mid
# Building Trajectory for  I-Can-Give-You-Anyting-But-Love.mid
# 970
# Building Trajectory for  I-Got-Rhythm.mid
# 1514
# Building Trajectory for  I-Left-My-Heart-In-San-Francisco-1.mid
# 491
# Building Trajectory for  Isle-Of-Capri.mid
# 1211
# Building Trajectory for  It-Ain't-Necessarily-So.mid
# 585
# Building Trajectory for  Jitterbu.mid
# 1637
# [5, 4] dict_items([(5, (1, 1))]) (1, 1) 3 2 1
# --> Cannot build Trajectory for  Jitterbu.mid
# Building Trajectory for  Just-Friends.mid
# 2386
# Building Trajectory for  Just-One-Of-Those-Things.mid
# 1493
# [3, 8] dict_items([(3, (105, 105))]) (105, 105) 3 2 1
# --> Cannot build Trajectory for  Just-One-Of-Those-Things.mid
# Building Trajectory for  Killing-Me-Softly-With-His-Song.mid
# 717
# Building Trajectory for  Lazy-Bird-1.mid
# 3607
# Building Trajectory for  Lazy-Bird-2.mid
# 3648
# Building Trajectory for  Li'l-Darling.mid
# 430
# Building Trajectory for  Like-Someone-In-Love.mid
# 1673
# Building Trajectory for  Loverman.mid
# 693
# Building Trajectory for  Lullaby-Of-Birdland.mid
# 2317
# Building Trajectory for  Mack-The-Knife.mid
# 1490
# Building Trajectory for  Makin'-Whoopee.mid
# 1035
# Building Trajectory for  Manteca.mid
# 643
# Building Trajectory for  Meditation.mid
# 850
# Building Trajectory for  Midnight-Blues.mid
# 632
# Building Trajectory for  Misty-1.mid
# 1748
# Building Trajectory for  Misty-2.mid
# 869
# Building Trajectory for  Moanin-1.mid
# 1934
# Building Trajectory for  Moanin-2.mid
# 509
# Building Trajectory for  Mood-Indigo.mid
# 556
# Building Trajectory for  More-1.mid
# 1699
# Building Trajectory for  More-2.mid
# 1277
# Building Trajectory for  My-Funny-Valentine-1.mid
# 845
# Building Trajectory for  My-Funny-Valentine-2.mid
# 845
# Building Trajectory for  My-Melancholy-Baby.mid
# 1317
# Building Trajectory for  My-One-And-Only-Love.mid
# 1288
# Building Trajectory for  New-York-New-York.mid
# 970
# Building Trajectory for  Nickleodian-Song.mid
# 1842
# Building Trajectory for  Night-And-Day-1.mid
# 1862
# Building Trajectory for  Night-And-Day.mid
# 3014
# Building Trajectory for  Oh-Lady-Be-Good.mid
# 2782
# [8, 2] dict_items([(8, (2, 5))]) (2, 5) 3 2 1
# --> Cannot build Trajectory for  Oh-Lady-Be-Good.mid
# Building Trajectory for  Old-Fashioned.mid
# 805
# Building Trajectory for  On-Green-Dolphin-Street.mid
# 2406
# Building Trajectory for  One-Morning-In-May.mid
# 1360
# Building Trajectory for  Out-Of-Nowhere.mid
# 1877
# Building Trajectory for  Parker.mid
# 1955
# Building Trajectory for  Pennies-From-Heaven.mid
# 999
# Building Trajectory for  Perfidia.mid
# 1265
# Building Trajectory for  Prelude-To-A-Kiss.mid
# 1657
# Building Trajectory for  Reet-Petite.mid
# 1098
# Building Trajectory for  Remarck.mid
# 1460

# %% [markdown]
# ### Storing

# %%
pickleSave(chopin, 'chopin')
pickleSave(chopinCorpus, 'chopinCorpus')

pickleSave(schumann, 'schumann')
pickleSave(schumannCorpus, 'schumannCorpus')

pickleSave(mozart, 'mozart')
pickleSave(mozartCorpus, 'mozartCorpus')

pickleSave(palestrina, 'palestrina')

pickleSave(monteverdi, 'monteverdi')

pickleSave(jazz, 'jazz')
